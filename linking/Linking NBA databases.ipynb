# %% [markdown]
# # Record Linkage for NBA Player Databases
#
#
# TL;DR: This notebook will walk through an example of using simple machine learning to perform record linkage for two NBA player databases (www.stats.nba.com and www.basketball-reference.com). I will show why this is (maybe) neccessary, provide explanations for the general steps inthe record linkage pipeline, and then execute this pipeline on the aformentioned data. If you have any questions/comments, or simply would like to see this done on more datasets, please feel free to reach out via email (hw.chase.17@gmail.com) or twitter (@aabsblog) - more than happy to chat.
#
# A lot of the code has been factored out into helper files and then imported here, mainly for making this notebook more readable. The factored out code may not be commented/explained as well as the code in here, but if you are looking at it and have questions feel free to reach out and I can try to add better documentation.
#
# I am also hoping to collect some feedback on this post and on my ideas for next steps. I would LOVE it if you spent 3 minutes filling out the forms after reading:
#
# [Give Feedback](https://forms.gle/R4mgQZS3oshG9vRGA)
#
# [Suggest Next Steps](https://forms.gle/PBBwh3519RuXpXsUA)

# %% [markdown]
# # Introduction
#
# #### What is record linkage?
#
# Record Linkage is the process of matching a record from one datasource to an record in another data source. This idea is not a new idea - [here is a paper](https://docs.lib.purdue.edu/cgi/viewcontent.cgi?article=2572&context=cstech) from 2003 that describes what is going on. At a high level, this paper describes three steps:
#
# 1. Searching Methods (also called *Blocking*): find somewhat similar records across two datasets
# 1. Comparision Functions (also called *Modeling*):  compare the pairs of records you found in Step 1 in a more detailed way
# 1. Decision Models (also called *Postprocessing*): make decisions based on Step 2
#
# #### Why should I care about record linkage?
#
# There is so much data on the internet these days. Even just considering basketball stats, I would say there are three main sites people go to for data: www.stats.nba.com, www.basketball-reference.com, and www.espn.com. Each of these sites contains their own datasets, with similar but perhaps slightly different information. While it is possible to get away with just using one of these sites, one can easily imagine that it might be desirable to pull in information from all three sites. Since all three sites have their own unique identifiers (or uuids) for each player, you would need to link these uuids to eachother.
#
# #### Why is it hard to link players from one datasource to another? Can't I just join on their name?
#
# The reason it is not trivial to do so is that a player's information may actually be slightly different accross the two sites. Names can be mispelled, nicknames could be used, years active could actually be different - all very small, but incredibly annoying things that make doing a join not possible - at least for all players.
#
# #### But surely it would be sufficient for most players?
#
# This is true. As I'll show in this notebook, a trivial join can join roughly 90% of players.
#
# #### If a trivial join works so well, is this linking exercise really neccessary?
#
# To be honest - no. If my goal was to simply link these two datasets I would use a trivial join, knock out 90% of the players, and then link the rest by hand - that would probably be faster than writing all this code.
#
# #### So then why did you do this?
# Two reasons. One, I think linking is an incredibly powerful tool and is useful in a ton of situations. In most situations you won't have a trivial rule to do joins on like you do here, and so this process is more neccessary. I wanted to give an example of this process, and I really like working with sports data, so I thought this would be a fun dataset. Second, having done this I could now actually use this for other tasks. Most simply, I could use this same pipeline, maybe even the same model, to link ESPN data to basketball-reference data. More complexly, I could probably use a lot of this pipeline to link football players, or soccer players, etc.

# %% [markdown]
# # Getting Data
#
# The first step in linking data is get said data. For this I have scraped data from www.stats.nba.com and www.basketball-reference.com.
#
# I've included the code for that as well as the results, so you if you want to replicate the rest of this pipeline you can just use the saved data.

# %% [markdown]
# ### Basketball reference

# %%
# Imports
import lxml
import requests
from bs4 import BeautifulSoup
from pysportsref.parsing import get_table_from_soup, get_table_soup
from pysportsref.scraping import get_soup
import string
import pandas as pd

# %%
# Scraping
player_dfs = []
for letter in string.ascii_lowercase:
    url = f"https://www.basketball-reference.com/players/{letter}/"
    soup = get_soup(url)

    table_str = get_table_soup(soup, 'players')

    bbref_df = get_table_from_soup(table_str, get_url=True)
    player_dfs.append(bbref_df)

bbref_df = pd.concat(player_dfs)

# %%
# Saving
bbref_df.to_csv('bbref_df.csv', index=False)

# %% [markdown]
# ### NBA.com

# %%
# Imports
from nba_api.stats.static import players
from nba_api.stats.endpoints.commonallplayers import CommonAllPlayers

# %%
# Scraping
all_players = CommonAllPlayers().get_dict()
data = all_players['resultSets'][0]['rowSet']
columns = columns=all_players['resultSets'][0]['headers']
nba_df = pd.DataFrame(data, columns=columns)

# %%
# Saving
nba_df.to_csv('nba_df.csv', index=False)

# %% [markdown]
# # Explore the data
#
# Lets first explore the data a bit. Several things I want to look at:
# 1. How many players in each dataset?
# 1. What peculiarities exist in each dataset?
# 1. How many can be matched by just joining on name and start year?

# %%
import pandas as pd

# %%
bbref_df = pd.read_csv('bbref_df.csv')
nba_df = pd.read_csv('nba_df.csv')

# %% [markdown]
# Q: How many players in each dataset?
#
# A: We can see from the below that there are 4865 players in the basketball reference dataset, and only 4589 in the nba.com dataset. This already suggests some differences in the datasets.

# %%
bbref_df.shape
# Out:
# (4865, 11)

# %%
nba_df.shape
# Out:
# (4589, 14)

# %% [markdown]
# Q: What peculiarities exist in each dataset?
#
# A: The main difference that exists is that the year accounting system used by nba.com is off by 1 from the accounting system used by basketball-reference. We can quickly adjust it so it is comparable.

# %%
nba_df['FROM_YEAR'] +=1
nba_df['TO_YEAR'] += 1

# %% [markdown]
# Q: How  many can be matched by just joining on name and start year?
#
# A: Looking at it below, we can create a `trival_uuid` that is just name and start year and then do a simple join on that. We can see that we can match 3906. To be honest, this is pretty good already - over 85% of the player can be matched by this. The remaining number is small enough where it may not be terrible to do it manually. However, lets pretend for educational purposes that we want to do this in an automated fashion

# %%
nba_df['trivial_uuid'] = nba_df['DISPLAY_FIRST_LAST'] + ' - ' + nba_df['FROM_YEAR'].astype(str)
bbref_df['trivial_uuid'] = bbref_df['player'] + ' - ' + bbref_df['year_min'].astype(int).astype(str)

# %%
merged = nba_df.merge(bbref_df, on='trivial_uuid', how='inner')

# %%
merged.shape
# Out:
# (3906, 26)

# %% [markdown]
# # Preprocessing
#
# Lets do some preprocessing to get the data clean and ready for record linkage.

# %%
from helpers import clean_name, preprocessing

# %%
bbref_df['clean_name'] = clean_name(bbref_df['player'])

# %%
nba_df['clean_name'] = clean_name(nba_df['DISPLAY_FIRST_LAST'])

# %%
bbref_df = preprocessing(bbref_df)
nba_df = preprocessing(nba_df)

# %%
bbref_df['uuid'] = bbref_df['player_url']
nba_df['uuid'] = nba_df['PERSON_ID']

# %%
bbref_df = bbref_df.rename(columns={'year_min': 'start_year', 'year_max': 'end_year'})
nba_df = nba_df.rename(columns={'FROM_YEAR': 'start_year', 'TO_YEAR': 'end_year'})

# %% [markdown]
# # Blocking
#
# Now lets do blocking. We do this by creating pairs for all players that either have the same first name OR the same last name.

# %%
from helpers import get_buckets, get_pairs

# %%
bbref_buckets = get_buckets(bbref_df)
nba_buckets = get_buckets(nba_df)

# %%
pairs = get_pairs(bbref_buckets, nba_buckets)

# %%
pair_df = pd.DataFrame(pairs, columns=['uuid_1', 'uuid_2'])

# %% [markdown]
# Of course, the above blocking logic is not neccessarily perfect. Let's take a look at whether any players had not been blocked at all. We see that we are missing a few from each database. Of course, this is not neccessarily bad - some players may only be in one database (in fact, we know there must be some players like this, since there are a differing number of players in each database).
#
# We can see that the nba.com database has mostly players who started this year that can't be blocked with anyone, while the basketball reference database has a bunch of historical players that can't be blocked. This is actually somewhat in line with expectations - nba.com is generally more up-to-date more quickly, while basketball reference has a bunch of ABA and historical players in different leagues, while nba.com only contains those who played in the NBA proper.

# %%
missing_bbref = set(bbref_df['uuid']).difference(pair_df['uuid_1'].unique())
len(missing_bbref)
# Out:
# 14

# %%
missing_nba = set(nba_df['uuid']).difference(pair_df['uuid_2'].unique())
len(missing_nba)
# Out:
# 6

# %%
nba_df[nba_df['uuid'].isin(missing_nba)]
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 346      202392          Blakely, Marqus     Marqus Blakely             0
# 998     1629603          Diakite, Mamadi     Mamadi Diakite             1
# 1587    1630204           Hagans, Ashton      Ashton Hagans             1
# 3071    1630168          Okongwu, Onyeka     Onyeka Okongwu             1
# 3510     202375            Rolle, Magnum       Magnum Rolle             0
# 3747    1629686       Sirvydis, Deividas  Deividas Sirvydis             1
#
#       start_year  end_year         PLAYERCODE     TEAM_ID  TEAM_CITY  \
# 346         2011      2011     marqus_blakely           0        NaN
# 998         2021      2021     mamadi_diakite  1610612749  Milwaukee
# 1587        2021      2021      ashton_hagans  1610612750  Minnesota
# 3071        2021      2021     onyeka_okongwi  1610612737    Atlanta
# 3510        2011      2011       magnum_rolle           0        NaN
# 3747        2021      2021  deividas_sirvydis  1610612765    Detroit
#
#          TEAM_NAME  ...     TEAM_CODE GAMES_PLAYED_FLAG  \
# 346            NaN  ...           NaN                 Y
# 998          Bucks  ...         bucks                 Y
# 1587  Timberwolves  ...  timberwolves                 Y
# 3071         Hawks  ...         hawks                 N
# 3510           NaN  ...           NaN                 Y
# 3747       Pistons  ...       pistons                 Y
#
#      OTHERLEAGUE_EXPERIENCE_CH              trivial_uuid         clean_name  \
# 346                          1     Marqus Blakely - 2011     marqus blakely
# 998                          0     Mamadi Diakite - 2021     mamadi diakite
# 1587                         0      Ashton Hagans - 2021      ashton hagans
# 3071                         0     Onyeka Okongwu - 2021     onyeka okongwu
# 3510                         1       Magnum Rolle - 2011       magnum rolle
# 3747                         0  Deividas Sirvydis - 2021  deividas sirvydis
#
#      clean_first_name clean_last_name suffix         basic_name     uuid
# 346            marqus         blakely            marqus blakely   202392
# 998            mamadi         diakite            mamadi diakite  1629603
# 1587           ashton          hagans             ashton hagans  1630204
# 3071           onyeka         okongwu            onyeka okongwu  1630168
# 3510           magnum           rolle              magnum rolle   202375
# 3747         deividas        sirvydis         deividas sirvydis  1629686
#
# [6 rows x 21 columns]

# %%
bbref_df[bbref_df['uuid'].isin(missing_bbref)]
# Out:
#               player  start_year  end_year  pos height  weight  \
# 436    Tommie Bowens      1968.0    1970.0  F-C    6-8   220.0
# 439    Orbie Bowling      1968.0    1968.0    C   6-10   215.0
# 685    Darel Carrier      1968.0    1973.0    G    6-3   185.0
# 1946  Carroll Hooser      1968.0    1968.0    F    6-7   230.0
# 2543     Leary Lentz      1968.0    1969.0    F    6-6   200.0
# 2590  Riney Lochmann      1968.0    1970.0    F    6-6   215.0
# 2640      R.B. Lynam      1968.0    1968.0    G    6-1   190.0
# 2915  Dewitt Menyard      1968.0    1968.0    C   6-10   210.0
# 3488  Marlbert Pradd      1968.0    1969.0    G    6-3   170.0
# 3811  Glynn Saulters      1969.0    1969.0    G    6-2   175.0
# 4095      Erv Staggs      1970.0    1970.0  F-G    6-6   195.0
# 4199     Levern Tart      1968.0    1971.0  G-F    6-2   195.0
# 4349   Ansley Truitt      1973.0    1973.0    C    6-9   215.0
# 4735  Vann Williford      1971.0    1971.0    F    6-6   195.0
#
#              birth_date                          colleges  \
# 436        July 7, 1940        Grambling State University
# 439      March 21, 1939                         Tennessee
# 685    October 26, 1940                  Western Kentucky
# 1946      March 5, 1944                               SMU
# 2543  February 23, 1945                           Houston
# 2590       May 26, 1944                            Kansas
# 2640                NaN       Oklahoma Baptist University
# 2915       May 24, 1944                              Utah
# 3488  November 17, 1944                Dillard University
# 3811  February 10, 1945                  Louisiana-Monroe
# 4095  September 1, 1948  North Carolina A&T, Cheyney (PA)
# 4199       June 1, 1942                           Bradley
# 4349    August 24, 1950                        California
# 4735   January 26, 1948                          NC State
#
#                      player_url                       birth_date_url  \
# 436   /players/b/bowento01.html    /friv/birthdays.cgi?month=7&day=7
# 439   /players/b/bowlior01.html   /friv/birthdays.cgi?month=3&day=21
# 685   /players/c/carrida01.html  /friv/birthdays.cgi?month=10&day=26
# 1946  /players/h/hooseca01.html    /friv/birthdays.cgi?month=3&day=5
# 2543  /players/l/lentzle01.html   /friv/birthdays.cgi?month=2&day=23
# 2590  /players/l/lochmri01.html   /friv/birthdays.cgi?month=5&day=26
# 2640  /players/l/lynamrb01.html                                  NaN
# 2915  /players/m/menyade01.html   /friv/birthdays.cgi?month=5&day=24
# 3488  /players/p/praddma01.html  /friv/birthdays.cgi?month=11&day=17
# 3811  /players/s/saultgl01.html   /friv/birthdays.cgi?month=2&day=10
# 4095  /players/s/stagger01.html    /friv/birthdays.cgi?month=9&day=1
# 4199   /players/t/tartle01.html    /friv/birthdays.cgi?month=6&day=1
# 4349  /players/t/truitan01.html   /friv/birthdays.cgi?month=8&day=24
# 4735  /players/w/williva01.html   /friv/birthdays.cgi?month=1&day=26
#
#                                 colleges_url           trivial_uuid  \
# 436    /friv/colleges.fcgi?college=grambling   Tommie Bowens - 1968
# 439    /friv/colleges.fcgi?college=tennessee   Orbie Bowling - 1968
# 685    /friv/colleges.fcgi?college=wkentucky   Darel Carrier - 1968
# 1946  /friv/colleges.fcgi?college=smethodist  Carroll Hooser - 1968
# 2543     /friv/colleges.fcgi?college=houston     Leary Lentz - 1968
# 2590      /friv/colleges.fcgi?college=kansas  Riney Lochmann - 1968
# 2640   /friv/colleges.fcgi?college=okbaptist      R.B. Lynam - 1968
# 2915        /friv/colleges.fcgi?college=utah  Dewitt Menyard - 1968
# 3488     /friv/colleges.fcgi?college=dillard  Marlbert Pradd - 1968
# 3811       /friv/colleges.fcgi?college=ulamo  Glynn Saulters - 1969
# 4095        /friv/colleges.fcgi?college=ncat      Erv Staggs - 1970
# 4199     /friv/colleges.fcgi?college=bradley     Levern Tart - 1968
# 4349  /friv/colleges.fcgi?college=california   Ansley Truitt - 1973
# 4735     /friv/colleges.fcgi?college=ncstate  Vann Williford - 1971
#
#           clean_name clean_first_name clean_last_name suffix      basic_name  \
# 436    tommie bowens           tommie          bowens          tommie bowens
# 439    orbie bowling            orbie         bowling          orbie bowling
# 685    darel carrier            darel         carrier          darel carrier
# 1946  carroll hooser          carroll          hooser         carroll hooser
# 2543     leary lentz            leary           lentz            leary lentz
# 2590  riney lochmann            riney        lochmann         riney lochmann
# 2640        rb lynam               rb           lynam               rb lynam
# 2915  dewitt menyard           dewitt         menyard         dewitt menyard
# 3488  marlbert pradd         marlbert           pradd         marlbert pradd
# 3811  glynn saulters            glynn        saulters         glynn saulters
# 4095      erv staggs              erv          staggs             erv staggs
# 4199     levern tart           levern            tart            levern tart
# 4349   ansley truitt           ansley          truitt          ansley truitt
# 4735  vann williford             vann       williford         vann williford
#
#                            uuid
# 436   /players/b/bowento01.html
# 439   /players/b/bowlior01.html
# 685   /players/c/carrida01.html
# 1946  /players/h/hooseca01.html
# 2543  /players/l/lentzle01.html
# 2590  /players/l/lochmri01.html
# 2640  /players/l/lynamrb01.html
# 2915  /players/m/menyade01.html
# 3488  /players/p/praddma01.html
# 3811  /players/s/saultgl01.html
# 4095  /players/s/stagger01.html
# 4199   /players/t/tartle01.html
# 4349  /players/t/truitan01.html
# 4735  /players/w/williva01.html

# %% [markdown]
# # Feature Engineering
#
# Now we do a bunch of feature engineering to create features to feed into our model that will predict whether two players are a match. I've put all of this code in the helper file to abstract it out a bit, but this is the main part of the code that requires any data science knowledge/intuition. Coming up with all these features was a combination of trying stuff out that I intuitively thought would be helpful, as well as doing error inspection on an earlier version of the model and then adding more features to hopefully "fix" those errors. Still, even this part isn't terribly complicated.

# %%
from helpers import create_features

# %%
columns_to_use = ['clean_name', 'basic_name', 'clean_first_name', 'clean_last_name', 'start_year', 'end_year', 'uuid', 'suffix']

# %%
feature_df = pair_df.merge(bbref_df[columns_to_use].add_suffix('_1'), how='left', on='uuid_1')
feature_df = feature_df.merge(nba_df[columns_to_use].add_suffix('_2'), how='left', on='uuid_2')

# %%
feature_df, features = create_features(feature_df)

# %% [markdown]
# # Getting labels
# Since we will be using supervised modeling techniques to train our model, we need some labels. How do we get those labels? We do this is two parts. First, we do some manually labeling. This mainly consists of labeling POSITIVE examples, ie two records that are a link. Then, since we know those are a link, and we are assuming no duplicate links are allowed, we can infer that every other player is NOT a link with those two.
#
# Practically, we start by providing only TWO labeled examples - LeBron James and Michael Jordan. We then take all the other players they were blocked with, and those are our negative examples. That sampling happens inside the helper function `get_label_df`.

# %%
initial_pos_labels = [
    ('/players/j/jamesle01.html', 2544),
    ('/players/j/jordami01.html', 893),
]

# %%
from helpers import get_label_df

# %%
label_df = get_label_df(initial_pos_labels, pair_df)

# %% [markdown]
# # Modeling
#
# Now for the "machine learning" part! For this I am going to keep it extremely simple and just use Logistic Regression. Although you can use fancier modeling techniques, because this is a relatively simple dataset/problem there is no real need to. Don't let people tell you need to use neural networks for no good reason! Keep it simple :)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
def get_mod(label_df, feature_df, features):
    mod = make_pipeline(StandardScaler(), LogisticRegression())
    df = pd.merge(label_df, feature_df, how='left', on=['uuid_1', 'uuid_2'])
    mod.fit(df[features], df['target'])
    return mod

# %%
mod = get_mod(label_df, feature_df, features)

# %% [markdown]
# # Let's do it for real!
#
# Now lets do it for real. The above model will not be amazing, since it is only trained on two positive examples. If we want to get a better model, the easiest way to do that at the moement is to just add more training examples.
#
# We can do this in two ways. First, we can use our basic way of linking players (join on name and year) and use some of the links produced via that method as training examples. Of course, if we only do that then our model will just learn that rule and that's kinda pointless. So I've also augmented our positive labels with some matches that that rule does NOT pick up. How did I come up with these? I trained a model based on initial labels, then found players that the model did not find a good match for, labeled those manually, and added those to the training dataset. Hopefully these labels we are adding are representative of other failures and therefor helps us learn some rules to link those!

# %%
import numpy as np

# %%
# Manually labeled points
initial_pos_labels = [
    ('/players/j/jamesle01.html', 2544),
    ('/players/j/jordami01.html', 893),
]
initial_pos_labels.extend([
    ('/players/l/lockro01.html', 77398),
    ('/players/w/weathcl01.html', 221),
    ('/players/e/ellisbo01.html', 76658),
    ('/players/c/coxch01.html', 76463),
    ('/players/p/paxsoji02.html', 77819),
    ('/players/p/paxsoji01.html', 77818),
    ('/players/p/paxsojo01.html', 77820),
    ('/players/j/jackslu02.html', 2739),
    ('/players/j/jackslu01.html', 77103),
    ('/players/s/silasja01.html', 78150),
    ('/players/e/elmorle01.html', 600010),
    ('/players/a/armstcu01.html', 76060),
    ('/players/j/johnsra01.html', 77139),
    ('/players/v/vaughch01.html', 78409),
    ('/players/t/taylofa01.html', 78302),
    ('/players/w/willidu01.html', 78545),
    ('/players/w/wallare01.html', 78443),
    ('/players/s/schafbo01.html', 78072),
    ('/players/d/davisch02.html', 76518),
    ('/players/p/portemi01.html', 1629008),
    ('/players/g/gillege01.html', 76813),
    ])

# %%
# Adding some labels from our trivial join
nba_df['clean_uuid'] = nba_df['clean_name'] + ' - ' + nba_df['start_year'].astype(str)
bbref_df['clean_uuid'] = bbref_df['clean_name'] + ' - ' + bbref_df['start_year'].astype(int).astype(str)
merged = nba_df.merge(bbref_df, on='clean_uuid', how='inner')
trivial_merged = merged.dropna(subset=['PERSON_ID', 'player_url'])
# These players can actually NOT be trivially merged
bad_uuids = {'tony mitchell - 2014', 'bill bradley - 1968', 'mark jones - 1984'}
trivial_merged = trivial_merged[~trivial_merged['clean_uuid'].isin(bad_uuids)]
trivial_matches = [(y, int(x)) for x,y in trivial_merged[['PERSON_ID', 'player_url']].values]

# %%
# Let's not add all these trivial matches to our training dataset, or else they will overwhelm the other examples. 
np.random.shuffle(trivial_matches)
initial_pos_labels.extend(trivial_matches[:400])

# %%
label_df = get_label_df(initial_pos_labels, pair_df)

# %%
mod = get_mod(label_df, feature_df, features)

# %% [markdown]
# # Predictions
#
# Now that we have a model, we can make predictions for all our pairs! For ease of postprocessing (the next step), we will transform these to the logit space.

# %%
from scipy.special import logit
preds = mod.predict_proba(feature_df[features], )
feature_df['probas'] = logit(preds[:, 1])

# %% [markdown]
# # Postprocessing
#
# Now we have predictions for each pair. But we don't want our final result to be predictions for each pair. Rather, we want it to be pairs of entities that we know are a match. So we need to perform some postprocessing to arrive there.
#
# Specifically, we can split the labels into three groups:
#
# 1. pairs of entities that we think are a match
# 1. entities from each database that we don't think have a match at all
# 1. entities (or pairs of entities) that we aren't sure about
#
# What makes us put entities in one group versus another?
#
# 1. In order to be sure that two entities are a match, they should be matched with high confidence and neither one should have any other matches with close to their confidence.
# 1. In order to be sure that an entity has no match, they should have no matches with high or medium confidence
# 1. Entities that we aren't sure about consist of entities that have a medium confidence match at best, or multiple high confidence matches.
#
# The reason I transformed predictions to the logit space is because I found it simpler/more intuitive to do this postprocessing in the logit space for this dataset. However, postprocessing can often be very dataset/project specific, and depends on how much tolerance you have for false postives/false negatives, and therefor should be tuned carefully.

# %%
def get_score_df(df):
    max_2 = df.groupby('uuid_2')['probas'].max().to_frame('max_2').reset_index()
    max_1 = df.groupby('uuid_1')['probas'].max().to_frame('max_1').reset_index()
    dif_2 = df.groupby('uuid_2').apply(_dif).to_frame('dif_2').reset_index()
    dif_1 = df.groupby('uuid_1').apply(_dif).to_frame('dif_1').reset_index()
    res_df = df.merge(max_2).merge(max_1).merge(dif_1).merge(dif_2)
    res_df['top_pick'] = (res_df['max_2'] == res_df['probas']) & (res_df['max_1'] == res_df['probas'])
    return res_df[['max_2', 'max_1', 'dif_1', 'dif_2', 'top_pick', 'uuid_1', 'uuid_2']]

# %%
def _dif(df):
    if df.shape[0] == 1:
        return np.inf
    else:
        return (df['probas'].max() - df['probas']).sort_values().iloc[1]

# %%
res_df = get_score_df(feature_df)

# %%
high_confidence_matches = res_df[res_df['top_pick'] & (res_df['dif_1'] > 3) & (res_df['dif_2'] > 3) & (res_df['max_2'] > 1)]

# %%
no_matches_1 = res_df.groupby('uuid_1')['max_1'].max()[lambda x: x < -1].index
no_matches_2 = res_df.groupby('uuid_2')['max_2'].max()[lambda x: x < -1].index

# %%
medium_uuids1 = set(bbref_df['uuid']).difference(no_matches_1).difference(high_confidence_matches['uuid_1'])
medium_uuids2 = set(nba_df['uuid']).difference(no_matches_2).difference(high_confidence_matches['uuid_2'])

# %% [markdown]
# # Examine results
#
# What follows is some simple examination of the results and sanity checking.

# %% [markdown]
# ### Found matches
#
# Examining found matches is maybe the most easy. We can first perform a simple sanity check and see how many of our "trivial matches" (joining based on unique name and start year) were linked. We would hope this to be 100%.

# %%
high_confidence_match_pairs = list(zip(high_confidence_matches['uuid_1'], high_confidence_matches['uuid_2']))

# %%
set(trivial_matches).difference(high_confidence_match_pairs)
# Out:
# set()

# %% [markdown]
# Yay! We get all the trivial matches. Verifying whether the other found matches are correct is similarly easy. Let's take a look at some of the matches that are NOT trivial matches and see what we are learning.

# %%
non_trivial_results = high_confidence_matches[~high_confidence_matches['uuid_1'].isin([pair[0] for pair in trivial_matches])]

# %%
non_trivial_results.head()
# Out:
#          max_2     max_1      dif_1      dif_2  top_pick  \
# 993   9.192834  9.192834  21.097861  19.671124      True
# 1042  9.171952  9.171952  22.577403  20.471072      True
# 2791  3.210996  3.210996  10.800137  13.746216      True
# 4408  2.244283  2.244283   9.654801  10.372107      True
# 6414  3.454891  3.454891  10.070342   9.523362      True
#
#                          uuid_1  uuid_2
# 993   /players/r/robisda01.html   77998
# 1042  /players/t/twardda01.html   78387
# 2791  /players/j/johnsch01.html   77133
# 4408  /players/j/johnsch02.html   77159
# 6414  /players/j/johnsra01.html   77139

# %%
bbref_df[bbref_df['uuid'] == '/players/a/ardji01.html']
# Out:
#       player  start_year  end_year  pos height  weight          birth_date  \
# 129  Jim Ard      1971.0    1978.0  F-C    6-8   215.0  September 19, 1948
#
#        colleges               player_url                      birth_date_url  \
# 129  Cincinnati  /players/a/ardji01.html  /friv/birthdays.cgi?month=9&day=19
#
#                           colleges_url    trivial_uuid clean_name  \
# 129  /friv/colleges.fcgi?college=cincy  Jim Ard - 1971    jim ard
#
#     clean_first_name clean_last_name suffix basic_name  \
# 129              jim             ard           jim ard
#
#                         uuid      clean_uuid
# 129  /players/a/ardji01.html  jim ard - 1971

# %%
nba_df[nba_df['uuid'] == 76055]
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 123      76055                 Ard, Jim            Jim Ard             0
#
#      start_year  end_year       PLAYERCODE  TEAM_ID TEAM_CITY TEAM_NAME  ...  \
# 123        1975      1978  HISTADD_jim_ard        0       NaN       NaN  ...
#
#     GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH    trivial_uuid  clean_name  \
# 123                 Y                         0  Jim Ard - 1975     jim ard
#
#     clean_first_name clean_last_name suffix basic_name   uuid      clean_uuid
# 123              jim             ard           jim ard  76055  jim ard - 1975
#
# [1 rows x 22 columns]

# %% [markdown]
# We can see that in this example, the start years of the players do not match up. This is just one of many small but annoying differences in the datasets that we are to "learn" through machine learning. I encourage you to look through the other links, and if you see any that are off let me know (or add them back into the training data and run again!)

# %% [markdown]
# ### No matches found
#
# Verifying the results of no matches found is a bit more tricky, since in order to confirm that a entity really does have no match we would have to basically look at all other entities in the dataset and confirm that they are not a match. But looking at that many pairs would take impossibly long, so we don't want to do that...
#
# First lets check out the players we are missing from each dataset

# %%
bbref_df[bbref_df['uuid'].isin(no_matches_1)]
# Out:
#                player  start_year  end_year  pos height  weight  \
# 18       George Adams      1973.0    1975.0  F-G    6-5   210.0
# 34      Matthew Aitch      1968.0    1968.0    F    6-7   230.0
# 57         Bill Allen      1968.0    1968.0  C-F    6-8   205.0
# 69       Willie Allen      1972.0    1972.0    F    6-6   230.0
# 85    Andrew Anderson      1968.0    1970.0    G    6-2   184.0
# ...               ...         ...       ...  ...    ...     ...
# 4801   Willie Worsley      1969.0    1969.0    G    5-9   175.0
# 4813     Howie Wright      1971.0    1972.0    G    6-3   185.0
# 4817     Leroy Wright      1968.0    1969.0    F    6-9   215.0
# 4818    Lonnie Wright      1968.0    1972.0    G    6-2   205.0
# 4824    Dennis Wuycik      1973.0    1975.0    F    6-6   215.0
#
#               birth_date                      colleges  \
# 18          May 15, 1949       Gardner-Webb University
# 34    September 21, 1944                Michigan State
# 57                   NaN              New Mexico State
# 69      February 8, 1949                    Miami (FL)
# 85          July 6, 1945                      Canisius
# ...                  ...                           ...
# 4801   November 13, 1945                 Texas-El Paso
# 4813   February 22, 1947  Austin Peay State University
# 4817         May 6, 1938     University of the Pacific
# 4818    January 23, 1945                Colorado State
# 4824      March 29, 1950                           UNC
#
#                      player_url                       birth_date_url  \
# 18    /players/a/adamsge01.html   /friv/birthdays.cgi?month=5&day=15
# 34    /players/a/aitchma01.html   /friv/birthdays.cgi?month=9&day=21
# 57    /players/a/allenbi01.html                                  NaN
# 69    /players/a/allenwi01.html    /friv/birthdays.cgi?month=2&day=8
# 85    /players/a/anderan01.html    /friv/birthdays.cgi?month=7&day=6
# ...                         ...                                  ...
# 4801  /players/w/worslwi01.html  /friv/birthdays.cgi?month=11&day=13
# 4813  /players/w/wrighho01.html   /friv/birthdays.cgi?month=2&day=22
# 4817  /players/w/wrighle01.html    /friv/birthdays.cgi?month=5&day=6
# 4818  /players/w/wrighlo01.html   /friv/birthdays.cgi?month=1&day=23
# 4824  /players/w/wuycide01.html   /friv/birthdays.cgi?month=3&day=29
#
#                                 colleges_url            trivial_uuid  \
# 18      /friv/colleges.fcgi?college=gardwebb     George Adams - 1973
# 34    /friv/colleges.fcgi?college=michiganst    Matthew Aitch - 1968
# 57       /friv/colleges.fcgi?college=nmstate       Bill Allen - 1968
# 69       /friv/colleges.fcgi?college=miamifl     Willie Allen - 1972
# 85      /friv/colleges.fcgi?college=canisius  Andrew Anderson - 1968
# ...                                      ...                     ...
# 4801        /friv/colleges.fcgi?college=utep   Willie Worsley - 1969
# 4813  /friv/colleges.fcgi?college=austinpeay     Howie Wright - 1971
# 4817     /friv/colleges.fcgi?college=pacific     Leroy Wright - 1968
# 4818  /friv/colleges.fcgi?college=coloradost    Lonnie Wright - 1968
# 4824         /friv/colleges.fcgi?college=unc    Dennis Wuycik - 1973
#
#            clean_name clean_first_name clean_last_name suffix  \
# 18       george adams           george           adams
# 34      matthew aitch          matthew           aitch
# 1293        2021      2021     trent_forrest  1610612762          Utah
# 1348        2010      2010      tony_gaffney           0           NaN
# 1673        2021      2021      jalen_harris  1610612761       Toronto
# 1692        2010      2010   kenny_hasbrouck           0           NaN
# 1794        2008      2008      herbert_hill           0           NaN
# 1944        2018      2021     frank_jackson  1610612765       Detroit
# 2011        2010      2010   curtis_jerrells           0           NaN
# 2393        2021      2021         saban_lee  1610612765       Detroit
# 2518        2021      2021   tmp_will_magnay  1610612740   New Orleans
# 2537        1997      1998       marcus_mann           0           NaN
# 2542        2021      2021      nico_mannion  1610612744  Golden State
# 2564        2021      2021     naji_marshall  1610612740   New Orleans
# 2590        2021      2021  kenyon_martin_jr  1610612745       Houston
# 3231        2019      2019     tarik_phillip           0           NaN
# 3385        2021      2021         paul_reed  1610612755  Philadelphia
# 3441        2021      2021      grant_riller  1610612766     Charlotte
# 3646        2021      2021        jay_scrubb  1610612746            LA
# 4060        2021      2021    killian_tillie  1610612763       Memphis
# 4147        2011      2011      robert_vaden           0           NaN
# 4355        2011      2011     terrico_white           0           NaN
# 4366        2021      2021  greg_whittington  1610612743        Denver
# 4498        2021      2021   cassius_winston  1610612764    Washington
# 4524        2020      2020      kenny_wooten           0           NaN
#
#       TEAM_NAME  ... GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH  \
# 363         NaN  ...                 Y                         1
# 586         NaN  ...                 Y                         1
# 590         NaN  ...                 N                         1
# 906     Hornets  ...                 Y                         0
# 1293       Jazz  ...                 Y                         0
# 1348        NaN  ...                 Y                         1
# 1673    Raptors  ...                 Y                         0
# 1692        NaN  ...                 Y                         1
# 1794        NaN  ...                 Y                         1
# 1944    Pistons  ...                 Y                         1
# 2011        NaN  ...                 Y                         1
# 2393    Pistons  ...                 Y                         0
# 2518   Pelicans  ...                 N                         0
# 2537        NaN  ...                 N                         0
# 2542   Warriors  ...                 Y                         0
# 2564   Pelicans  ...                 N                         0
# 2590    Rockets  ...                 Y                         0
# 3231        NaN  ...                 N                         1
# 3385      76ers  ...                 Y                         0
# 3441    Hornets  ...                 Y                         0
# 3646   Clippers  ...                 N                         0
# 4060  Grizzlies  ...                 N                         0
# 4147        NaN  ...                 N                         1
# 4355        NaN  ...                 Y                         1
# 4366    Nuggets  ...                 Y                         1
# 4498    Wizards  ...                 Y                         0
# 4524        NaN  ...                 Y                         1
#
#                   trivial_uuid        clean_name clean_first_name  \
# 363      Trevon Bluiett - 2019    trevon bluiett           trevon
# 586         Brian Butch - 2010       brian butch            brian
# 590      Da'Sean Butler - 2011     dasean butler           dasean
# 906        Nate Darling - 2021      nate darling             nate
# 1293      Trent Forrest - 2021     trent forrest            trent
# 1348       Tony Gaffney - 2010      tony gaffney             tony
# 1673       Jalen Harris - 2021      jalen harris            jalen
# 1692    Kenny Hasbrouck - 2010   kenny hasbrouck            kenny
# 1794       Herbert Hill - 2008      herbert hill          herbert
# 1944      Frank Jackson - 2018     frank jackson            frank
# 2011    Curtis Jerrells - 2010   curtis jerrells           curtis
# 2393          Saben Lee - 2021         saben lee            saben
# 2518        Will Magnay - 2021       will magnay             will
# 2537        Marcus Mann - 1997       marcus mann           marcus
# 2542       Nico Mannion - 2021      nico mannion             nico
# 2564      Naji Marshall - 2021     naji marshall             naji
# 2590  Kenyon Martin Jr. - 2021  kenyon martin jr           kenyon
# 3231      Tarik Phillip - 2019     tarik phillip            tarik
# 3385          Paul Reed - 2021         paul reed             paul
# 3441       Grant Riller - 2021      grant riller            grant
# 3646         Jay Scrubb - 2021        jay scrubb              jay
# 4060     Killian Tillie - 2021    killian tillie          killian
# 4147       Robert Vaden - 2011      robert vaden           robert
# 4355      Terrico White - 2011     terrico white          terrico
# 4366   Greg Whittington - 2021  greg whittington             greg
# 4498    Cassius Winston - 2021   cassius winston          cassius
# 4524       Kenny Wooten - 2020      kenny wooten            kenny
#
#      clean_last_name suffix        basic_name     uuid  \
# 363          bluiett           trevon bluiett  1629129
# 586            butch              brian butch   202221
# 590           butler            dasean butler   202364
# 906          darling             nate darling  1630268
# 1293         forrest            trent forrest  1630235
# 1348         gaffney             tony gaffney   202070
# 1673          harris             jalen harris  1630223
# 1692       hasbrouck          kenny hasbrouck   202238
# 1794            hill             herbert hill   201195
# 1944         jackson            frank jackson  1628402
# 2011        jerrells          curtis jerrells   201998
# 2393             lee                saben lee  1630240
# 2518          magnay              will magnay  1630266
# 2537            mann              marcus mann      986
# 2542         mannion             nico mannion  1630185
# 2564        marshall            naji marshall  1630230
# 2590          martin     jr     kenyon martin  1630231
# 3231         phillip            tarik phillip  1629341
# 3385            reed                paul reed  1630194
# 3441          riller             grant riller  1630203
# 3646          scrubb               jay scrubb  1630206
# 4060          tillie           killian tillie  1629681
# 4147           vaden             robert vaden   201987
# 4355           white            terrico white   202358
# 4366     whittington         greg whittington   204222
# 4498         winston          cassius winston  1630216
# 4524          wooten             kenny wooten  1629624
#
#                    clean_uuid
# 363     trevon bluiett - 2019
# 586        brian butch - 2010
# 590      dasean butler - 2011
# 906       nate darling - 2021
# 1293     trent forrest - 2021
# 1348      tony gaffney - 2010
# 1673      jalen harris - 2021
# 1692   kenny hasbrouck - 2010
# 1794      herbert hill - 2008
# 1944     frank jackson - 2018
# 2011   curtis jerrells - 2010
# 2393         saben lee - 2021
# 2518       will magnay - 2021
# 2537       marcus mann - 1997
# 2542      nico mannion - 2021
# 2564     naji marshall - 2021
# 2590  kenyon martin jr - 2021
# 3231     tarik phillip - 2019
# 3385         paul reed - 2021
# 3441      grant riller - 2021
# 3646        jay scrubb - 2021
# 4060    killian tillie - 2021
# 4147      robert vaden - 2011
# 4355     terrico white - 2011
# 4366  greg whittington - 2021
# 4498   cassius winston - 2021
# 4524      kenny wooten - 2020
#
# [27 rows x 22 columns]

# %% [markdown]
# What do we see? We see that for basketball reference players, we are missing links for older players. This is not a huge surprise - as stated before, basketball reference has a lot of old ABA players that nba.com is missing.
#
# For nba.com, we see that we are missing a lot of players that only played a single year, and a lot of those are new this year. Again, not terribly surprising given that as stated before I have noticed nba.com to be slightly better at updating their player lists for recent players.
#
# Still, to be honest I haven't gone over each any everyone of these. There is definitely the possibility for errors. If you find some, you know what to do - let me know, or just add it to the training data and create a feature or two!

# %% [markdown]
# ### Unsure entities
#
# The following are entities that we are not sure about. For these, in a production setting I would like these to be hand labeled. Rather than labeling all of them, if you sense that there are common themes you could label some, retrain the model, and hope that this group shrinks.

# %%
bbref_df[bbref_df['uuid'].isin(medium_uuids1)]
# Out:
#                    player  start_year  end_year  pos height  weight  \
# 143            Bob Arnzen      1970.0    1974.0    F    6-5   205.0
# 287         Arthur Becker      1968.0    1973.0    F    6-7   205.0
# 436         Tommie Bowens      1968.0    1970.0  F-C    6-8   220.0
# 439         Orbie Bowling      1968.0    1968.0    C   6-10   215.0
# 457          Bill Bradley      1968.0    1968.0    G   5-11   165.0
# 685         Darel Carrier      1968.0    1973.0    G    6-3   185.0
# 993          Mickey Davis      1972.0    1977.0  F-G    6-7   195.0
# 1679          Robert Hahn      1950.0    1950.0    C   6-10   240.0
# 1765         Billy Harris      1975.0    1975.0    G    6-2   185.0
# 1946       Carroll Hooser      1968.0    1968.0    F    6-7   230.0
# 2157           Ed Johnson      1969.0    1971.0    C    6-8   205.0
# 2232          Hutch Jones      1983.0    1984.0    F    6-8   190.0
# 2408           Tom Kondla      1969.0    1969.0    C    6-8   225.0
# 2543          Leary Lentz      1968.0    1969.0    F    6-6   200.0
# 2584  Horacio Llamas Grey      1997.0    1998.0    C   6-11   285.0
# 2590       Riney Lochmann      1968.0    1970.0    F    6-6   215.0
# 2640           R.B. Lynam      1968.0    1968.0    G    6-1   190.0
# 2676        Brian Mahoney      1973.0    1973.0    G    6-3   175.0
# 2697          Guy Manning      1968.0    1969.0    F    6-6   195.0
# 2915       Dewitt Menyard      1968.0    1968.0    C   6-10   210.0
# 2983        Tony Mitchell      2014.0    2014.0    F    6-6   216.0
# 2984        Tony Mitchell      2014.0    2014.0    F    6-8   235.0
# 3468         Kevin Porter      2020.0    2020.0    G    6-4   203.0
# 3488       Marlbert Pradd      1968.0    1969.0    G    6-3   170.0
# 3793           Al Sanders      1973.0    1973.0    F    6-7   240.0
# 3811       Glynn Saulters      1969.0    1969.0    G    6-2   175.0
# 4047        William Smith      1972.0    1973.0    C    7-0   220.0
# 4095           Erv Staggs      1970.0    1970.0  F-G    6-6   195.0
# 4199          Levern Tart      1968.0    1971.0  G-F    6-2   195.0
# 4349        Ansley Truitt      1973.0    1973.0    C    6-9   215.0
# 4489          Red Wallace      1947.0    1947.0    G    6-1   185.0
# 4654          Al Williams      1971.0    1971.0    F    6-6   200.0
# 4663     Charles Williams      1968.0    1973.0    G    6-0   165.0
# 4670        Duck Williams      1980.0    1980.0    G    6-2   180.0
# 4735       Vann Williford      1971.0    1971.0    F    6-6   195.0
# 4742         Bubba Wilson      1980.0    1980.0    G    6-3   175.0
#
#              birth_date                          colleges  \
# 143    November 3, 1947                        Notre Dame
# 287    January 12, 1942                     Arizona State
# 436        July 7, 1940        Grambling State University
# 439      March 21, 1939                         Tennessee
# 4199     /friv/colleges.fcgi?college=bradley          Levern Tart - 1968
# 4349  /friv/colleges.fcgi?college=california        Ansley Truitt - 1973
# 4489    /friv/colleges.fcgi?college=scranton          Red Wallace - 1947
# 4654       /friv/colleges.fcgi?college=drake          Al Williams - 1971
# 4663     /friv/colleges.fcgi?college=seattle     Charles Williams - 1968
# 4670   /friv/colleges.fcgi?college=notredame        Duck Williams - 1980
# 4735     /friv/colleges.fcgi?college=ncstate       Vann Williford - 1971
# 4742   /friv/colleges.fcgi?college=wcarolina         Bubba Wilson - 1980
#
#                clean_name clean_first_name clean_last_name suffix  \
# 143            bob arnzen              bob          arnzen
# 287         arthur becker           arthur          becker
# 436         tommie bowens           tommie          bowens
# 439         orbie bowling            orbie         bowling
# 457          bill bradley             bill         bradley
# 685         darel carrier            darel         carrier
# 993          mickey davis           mickey           davis
# 1679          robert hahn           robert            hahn
# 1765         billy harris            billy          harris
# 1946       carroll hooser          carroll          hooser
# 2157           ed johnson               ed         johnson
# 2232          hutch jones            hutch           jones
# 2408           tom kondla              tom          kondla
# 2543          leary lentz            leary           lentz
# 2584  horacio llamas grey          horacio            grey
# 2590       riney lochmann            riney        lochmann
# 2640             rb lynam               rb           lynam
# 2676        brian mahoney            brian         mahoney
# 2697          guy manning              guy         manning
# 2915       dewitt menyard           dewitt         menyard
# 2983        tony mitchell             tony        mitchell
# 2984        tony mitchell             tony        mitchell
# 3468         kevin porter            kevin          porter
# 3488       marlbert pradd         marlbert           pradd
# 3793           al sanders               al         sanders
# 3811       glynn saulters            glynn        saulters
# 4047        william smith          william           smith
# 4095           erv staggs              erv          staggs
# 4199          levern tart           levern            tart
# 4349        ansley truitt           ansley          truitt
# 4489          red wallace              red         wallace
# 4654          al williams               al        williams
# 4663     charles williams          charles        williams
# 4670        duck williams             duck        williams
# 4735       vann williford             vann       williford
# 4742         bubba wilson            bubba          wilson
#
#                basic_name                       uuid  \
# 143            bob arnzen  /players/a/arnzebo01.html
# 287         arthur becker  /players/b/beckear01.html
# 436         tommie bowens  /players/b/bowento01.html
# 439         orbie bowling  /players/b/bowlior01.html
# 457          bill bradley  /players/b/bradlbi02.html
# 685         darel carrier  /players/c/carrida01.html
# 993          mickey davis  /players/d/davismi02.html
# 1679          robert hahn   /players/h/hahnro01.html
# 1765         billy harris  /players/h/harribi01.html
# 1946       carroll hooser  /players/h/hooseca01.html
# 2157           ed johnson  /players/j/johnsed01.html
# 2232          hutch jones  /players/j/joneshu01.html
# 2408           tom kondla  /players/k/kondlto01.html
# 2543          leary lentz  /players/l/lentzle01.html
# 2584  horacio llamas grey  /players/l/llamaho01.html
# 2590       riney lochmann  /players/l/lochmri01.html
# 2640             rb lynam  /players/l/lynamrb01.html
# 2676        brian mahoney  /players/m/mahonbr01.html
# 2697          guy manning  /players/m/mannigu01.html
# 2915       dewitt menyard  /players/m/menyade01.html
# 2983        tony mitchell  /players/m/mitchto03.html
# 2984        tony mitchell  /players/m/mitchto02.html
# 3468         kevin porter  /players/p/porteke02.html
# 4484      78587           Wilson, Thomas      Thomas Wilson             0
#
#       start_year  end_year             PLAYERCODE     TEAM_ID  TEAM_CITY  \
# 137         1971      1971     HISTADD_bob_arnzen           0        NaN
# 312         2021      2021              tyler_bey  1610612742     Dallas
# 346         2011      2011         marqus_blakely           0        NaN
# 929         1973      1977   HISTADD_mickey_davis           0        NaN
# 998         2021      2021         mamadi_diakite  1610612749  Milwaukee
# 1587        2021      2021          ashton_hagans  1610612750  Minnesota
# 1588        1950      1950       HISTADD_bob_hahn           0        NaN
# 2125        2021      2021            mason_jones  1610612745    Houston
# 2142        1983      1984    HISTADD_hutch_jones           0        NaN
# 2436        1997      2003         horacio_llamas           0        NaN
# 2817        2014      2014          tony_mitchell           0        NaN
# 2818        2014      2014          tony_mitchell           0        NaN
# 3071        2021      2021         onyeka_okongwi  1610612737    Atlanta
# 3275        2020      2021          jontay_porter  1610612763    Memphis
# 3278        2020      2021        kevin_porter_jr  1610612739  Cleveland
# 3510        2011      2011           magnum_rolle           0        NaN
# 3733        2012      2012         diamon_simpson           0        NaN
# 3747        2021      2021      deividas_sirvydis  1610612765    Detroit
# 3770        1972      1973     HISTADD_bill_smith           0        NaN
# 4235        1947      1947    HISTADD_red_wallace           0        NaN
# 4408        1980      1980  HISTADD_duck_williams           0        NaN
# 4484        1980      1980   HISTADD_bubba_wilson           0        NaN
#
#          TEAM_NAME  ... GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH  \
# 137            NaN  ...                 Y                         0
# 312      Mavericks  ...                 Y                         0
# 346            NaN  ...                 Y                         1
# 929            NaN  ...                 Y                         0
# 998          Bucks  ...                 Y                         0
# 1587  Timberwolves  ...                 Y                         0
# 1588           NaN  ...                 Y                         0
# 2125       Rockets  ...                 Y                         0
# 2142           NaN  ...                 Y                         0
# 2436           NaN  ...                 Y                         0
# 2817           NaN  ...                 Y                         1
# 2818           NaN  ...                 Y                         1
# 3071         Hawks  ...                 N                         0
# 3275     Grizzlies  ...                 N                         0
# 3278     Cavaliers  ...                 Y                         0
# 3510           NaN  ...                 Y                         1
# 3733           NaN  ...                 N                         1
# 3747       Pistons  ...                 Y                         0
# 3770           NaN  ...                 Y                         0
# 4235           NaN  ...                 Y                         0
# 4408           NaN  ...                 Y                         0
# 4484           NaN  ...                 Y                         0
#
#                   trivial_uuid         clean_name clean_first_name  \
# 137          Bob Arnzen - 1971         bob arnzen              bob
# 312           Tyler Bey - 2021          tyler bey            tyler
# 346      Marqus Blakely - 2011     marqus blakely           marqus
# 929        Edward Davis - 1973       edward davis           edward
# 998      Mamadi Diakite - 2021     mamadi diakite           mamadi
# 1587      Ashton Hagans - 2021      ashton hagans           ashton
# 1588           Bob Hahn - 1950           bob hahn              bob
# 2125        Mason Jones - 2021        mason jones            mason
# 2142       Willie Jones - 1983       willie jones           willie
# 2436     Horacio Llamas - 1997     horacio llamas          horacio
# 2817      Tony Mitchell - 2014      tony mitchell             tony
# 2818      Tony Mitchell - 2014      tony mitchell             tony
# 3071     Onyeka Okongwu - 2021     onyeka okongwu           onyeka
# 3275      Jontay Porter - 2020      jontay porter           jontay
# 3278   Kevin Porter Jr. - 2020    kevin porter jr            kevin
# 3510       Magnum Rolle - 2011       magnum rolle           magnum
# 3733     Diamon Simpson - 2012     diamon simpson           diamon
# 3747  Deividas Sirvydis - 2021  deividas sirvydis         deividas
# 3770         Bill Smith - 1972         bill smith             bill
# 4235    Michael Wallace - 1947    michael wallace          michael
# 4408       Don Williams - 1980       don williams              don
# 4484      Thomas Wilson - 1980      thomas wilson           thomas
#
#      clean_last_name suffix         basic_name     uuid  \
# 137           arnzen                bob arnzen    76064
# 312              bey                 tyler bey  1630189
# 346          blakely            marqus blakely   202392
# 929            davis              edward davis    76522
# 998          diakite            mamadi diakite  1629603
# 1587          hagans             ashton hagans  1630204
# 1588            hahn                  bob hahn    76914
# 2125           jones               mason jones  1630222
# 2142           jones              willie jones    77203
# 2436          llamas            horacio llamas     1024
# 2817        mitchell             tony mitchell   203183
# 2818        mitchell             tony mitchell   203502
# 3071         okongwu            onyeka okongwu  1630168
# 3275          porter             jontay porter  1629007
# 3278          porter     jr       kevin porter  1629645
# 3510           rolle              magnum rolle   202375
# 3733         simpson            diamon simpson   202067
# 3747        sirvydis         deividas sirvydis  1629686
# 3770           smith                bill smith    78207
# 4235         wallace           michael wallace    78443
# 4408        williams              don williams    78545
# 4484          wilson             thomas wilson    78587
#
#                     clean_uuid
# 137          bob arnzen - 1971
# 312           tyler bey - 2021
# 346      marqus blakely - 2011
# 929        edward davis - 1973
# 998      mamadi diakite - 2021
# 1587      ashton hagans - 2021
# 1588           bob hahn - 1950
# 2125        mason jones - 2021
# 2142       willie jones - 1983
# 2436     horacio llamas - 1997
# 2817      tony mitchell - 2014
# 2818      tony mitchell - 2014
# 3071     onyeka okongwu - 2021
# 3275      jontay porter - 2020
# 3278    kevin porter jr - 2020
# 3510       magnum rolle - 2011
# 3733     diamon simpson - 2012
# 3747  deividas sirvydis - 2021
# 3770         bill smith - 1972
# 4235    michael wallace - 1947
# 4408       don williams - 1980
# 4484      thomas wilson - 1980
#
# [22 rows x 22 columns]

# %% [markdown]
# # Saving Results
#
# Honestly, a whole separate article could be dedicated to how to properly store and update links between entities overtime. The main gist is that these links we've generated are *probabilistic*, and I would actually *expect* that a good number of them are wrong. Therefore, when storing them we need to make to store them in a way where we can update and overwrite them if neccessary.
#
# Still, that is a separate concept. For this, I will just save the successfully linked entities in csv form. NOTE: there are still a bunch of entities not in this saved csv (the ones that have no match, and the ones we weren't sure about).

# %%
high_confidence_matches[['uuid_1', 'uuid_2']].rename(columns={'uuid_1': 'bbref_id', 'uuid_2': 'nba_id'}).to_csv('high_confidence_matches.csv', index=False)

# %% [markdown]
# # Conclusion

# %% [markdown]
# I am also hoping to collect some feedback on this post and on my ideas for next steps. I would LOVE it if you spent 3 minutes filling out the forms after reading:
#
# [Give Feedback](https://forms.gle/R4mgQZS3oshG9vRGA)
#
# [Suggest Next Steps](https://forms.gle/PBBwh3519RuXpXsUA)
