# %%
from bs4 import BeautifulSoup, Comment
import numpy as np
import pandas as pd
import sqlite3


def extract_table(table_str, header_row=1, start_of_rows=2, get_url=False):
    """Extract table from html."""
    columns = [t['data-stat'] for t in table_str.findAll('tr')[header_row].findAll('th')]
    rows = [
        [r.find('th').text] +
        [t.text for t in r.findAll('td')] for r in table_str.findAll('tr')[start_of_rows:]
    ]
    df = pd.DataFrame(rows, columns=columns)
    if get_url:
        extra_rows = [[t.find('a')['href'] if t.find('a') else np.nan for t in r.findAll('td')]
                      for r in table_str.findAll('tr')[start_of_rows:]]
        extra_df = pd.DataFrame(extra_rows, columns=[c+'_url' for c in columns[1:]])
        df = pd.concat([df, extra_df], axis=1)
    return df


def find_table(soup, table_name):
    """Find html for table, even if in a comment."""
    tables = soup.findAll('table', {"id": table_name})
    if tables:
        return tables[0]
    comments = soup.findAll(text=lambda text: isinstance(text, Comment))
    table_comment = next(c for c in comments if 'id="{}"'.format(table_name) in c)
    table_soup = BeautifulSoup(str(table_comment), "lxml")
    return table_soup.findAll('table', {"id": table_name})[0]


def create_insert_table_sql(table_name, col_mappings):
    """Create sql for creating and inserting a table."""
    col_types = ', '.join([k + ' ' + v for k, v in col_mappings.items()])
    create_sql = 'CREATE TABLE {} ({})'.format(table_name, col_types)
    placeholders = ', '.join(['?' for _ in col_mappings.items()])
    insert_sql = 'INSERT INTO {} VALUES ({})'.format(table_name, placeholders)
    return create_sql, insert_sql


def save_df_to_sqlite(sqlite_db, df, cols, table_name):
    """Helper to save df to sqlite."""
    with sqlite3.connect(sqlite_db) as conn:
        cur = conn.cursor()
        create_sql, insert_sql = create_insert_table_sql(table_name, cols)
        cur.execute(create_sql)
        cur.executemany(insert_sql, df[list(cols.keys())].values)

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import tqdm
import sys
import numpy as np
import pandas as pd
#sys.path.insert(0, "/Users/harrisonchase/workplace/sports/")

#from clean_sports_work.sports_reference.api import find_table, extract_table, create_insert_table_sql

# %%
all_dfs = []
for year in tqdm.tqdm(range(1950, 2020)):
    url = 'https://www.basketball-reference.com/leagues/NBA_{}_advanced.html'.format(year)
    html = urlopen(url)

    # create the BeautifulSoup object
    soup = BeautifulSoup(html, "lxml")

    table_str = find_table(soup, 'advanced_stats')

    yr2018 = extract_table(table_str, header_row=0, get_url=True, start_of_rows=1)
    drop_cols = yr2018.isnull().mean()[lambda x: x == 1].index
    for col in drop_cols:
        del yr2018[col]
    yr2018['year'] = year
    all_dfs.append(yr2018)
# Out:
# 100%|██████████| 70/70 [03:07<00:00,  3.68s/it]

# %%
all_stats = pd.concat(all_dfs)

# %%
all_stats = all_stats.dropna(subset=['player_url', 'mp', 'age'])

# %%
all_stats = all_stats.replace('', np.nan)

# %%
float_cols = ['bpm', 'ts_pct', 'per', 'usg_pct', 'obpm', 'dbpm', 
              'fg3a_per_fga_pct', 'fta_per_fga_pct', 'orb_pct', 'drb_pct',
             'trb_pct', 'ast_pct', 'stl_pct', 'blk_pct', 'tov_pct', 'ws', 'ows', 'dws']
for col in float_cols:
    all_stats[col] = all_stats[col].astype(float)
    
int_cols = ['mp', 'age']
for col in int_cols:
    all_stats[col] = all_stats[col].astype(int)
# Out:
# /Users/harrisonchase/workplace/.venvs/record_linking/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/harrisonchase/workplace/.venvs/record_linking/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
all_stats['id'] = all_stats['player_url'] + '___' + all_stats['year'].astype(str)
# Out:
# /Users/harrisonchase/workplace/.venvs/record_linking/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
multiple_ids = all_stats['id'].value_counts()[lambda x: x> 1].index

# %%
base_all_stats = pd.concat([
    all_stats[~all_stats['id'].isin(multiple_ids)],
    all_stats[all_stats['id'].isin(multiple_ids) & (all_stats['team_id'] == 'TOT')],
])

# %%
most_recent_year = base_all_stats[base_all_stats['year'] == base_all_stats['year'].max()]
most_recent_year['year'] += 1
most_recent_year['age'] +=1
most_recent_year['id'] = most_recent_year['player_url'] + '___' + most_recent_year['year'].astype(str)
# Out:
# /Users/harrisonchase/workplace/.venvs/record_linking/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/harrisonchase/workplace/.venvs/record_linking/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/harrisonchase/workplace/.venvs/record_linking/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
all_stats = pd.concat([base_all_stats, most_recent_year])

# %%
target = all_stats[['player_url', 'year', 'ws', 'id', 'bpm']]

# %%
def get_stats(all_stats, year_change):
    all_prior_stats = all_stats.copy()
    all_prior_stats['year'] += year_change
    all_prior_stats['id'] = all_prior_stats['player_url'] + '___' + all_prior_stats['year'].astype(str)
    cols = ['mp', 'bpm', 'ts_pct', 'per', 'usg_pct', 'obpm', 'dbpm',
            'fg3a_per_fga_pct', 'fta_per_fga_pct', 'orb_pct', 'drb_pct',
             'trb_pct', 'ast_pct', 'stl_pct', 'blk_pct', 'tov_pct', 'ws', 'ows', 'dws']
    return all_prior_stats[['id'] + cols].rename(columns={col: '{}___{}'.format(col, year_change) for col in cols})

# %%
def merge_dfs(target_df, *args):
    res = target_df
    for arg in args:
        cols = arg.columns
        intersection = set(res.columns).intersection(cols)
        if intersection != {'id'}:
            raise ValueError
        else:
            res = res.merge(arg, how='left', on='id')
    return res

# %%
all_stats['pos'] = all_stats['pos'].str.split('-').str[0]

# %%
X_df1 = pd.concat([all_stats[['id', 'age', 'mp']], pd.get_dummies(all_stats['pos'])], axis=1)

# %%
year_in_league = target.merge(target.groupby('player_url')['year'].min().to_frame('min_year').reset_index())
year_in_league['years_pro'] = year_in_league['year'] - year_in_league['min_year']
year_in_league = year_in_league[['id', 'years_pro']]

# %%
all_df = merge_dfs(
    target, 
    X_df1, 
    year_in_league,
    get_stats(all_stats, 1),
    get_stats(all_stats, 2),
    get_stats(all_stats, 3),
).dropna(subset=['bpm'])

# %%
all_df['lot_of_min'] = (all_df['mp___1'].fillna(0) + all_df['mp___2'].fillna(0)) > 1000

# %%
all_df['ws_diff'] = all_df['ws___1'] - all_df['ws___2']
all_df['bpm_diff'] = all_df['bpm___1'] - all_df['bpm___2']
all_df['mp_diff'] = all_df['mp___1'] - all_df['mp___2']
all_df['bpm_int'] = all_df['bpm___1'] * all_df['bpm___2']
all_df['bpm_diff_2'] = all_df['bpm___2'] - all_df['bpm___3']
all_df['bpm_age_int'] = all_df['bpm___1'] * all_df['age']

# %%
all_df['diff'] = all_df['bpm'] - all_df['bpm___1']

# %%
train_df = all_df[
    (all_df['year'] > 1970) 
    & (all_df['year'] < 2019) 
    & (all_df['years_pro'] > 0) 
    &(all_df['diff'].notnull())
]

# %%
import lightgbm as lgb
lgb_params = {
    'boosting_type': 'gbdt',
    'metric': ['rmse'],
    #'num_leaves': 20,
    'learning_rate': 0.05,
    #'feature_fraction': 0.6,
    #'bagging_fraction': 0.6,
    #'bagging_freq': 1,
    #'bagging_freq': 5,
    #'colsample_bytree': .4,
    #'min_data_in_leaf': 2,
    #'reg_alpha': 1,
    #'reg_lambda': 1,
    #'max_depth': 4,
    'verbose': 0
}

# %%
y = train_df['diff']
drop_cols =['id', 'ws', 'bpm', 'player_url', 'year', 'mp', 'diff']
X = train_df.drop(drop_cols, 1)
X_all = all_df.drop(drop_cols, 1)

# %%
weights = np.log10(train_df['mp']+1) #* 0 + 1

# %%
lgb_data = lgb.Dataset(X, y, weight=weights)
out = lgb.cv(lgb_params, lgb_data, num_boost_round=10000, nfold=5,
             early_stopping_rounds=10,stratified=False)
cv_loss = out['rmse-mean'][-1]
cv_num_rounds = len(out['rmse-mean'])

cv_loss, cv_num_rounds
# Out:
# (2.39418222760402, 152)

# %%
bst = lgb.LGBMRegressor(n_estimators=cv_num_rounds, **lgb_params)
bst.fit(X, y, sample_weight=weights)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.05, max_depth=-1,
#               metric=['rmse'], min_child_samples=20, min_child_weight=0.001,
#               min_split_gain=0.0, n_estimators=152, n_jobs=-1, num_leaves=31,
#               objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,
#               silent=True, subsample=1.0, subsample_for_bin=200000,
#               subsample_freq=0, verbose=0)

# %%
preds = bst.predict(X_all)

# %%
pred_df = all_df.copy()
pred_df['pred'] = preds + pred_df['bpm___1']

# %%
recent = pred_df[(pred_df['year'] > 2018) & (pred_df['year'] < 2020)].sort_values('pred')
recent = recent[(recent['years_pro'] > 0)]

# %%
(((recent['bpm'] - recent['pred'])**2)**.5).mean()
# Out:
# 2.1676610734861486

# %%
recent.merge(recent1[['id', 'pred']], on='id')
# Out:
#                     player_url  year    ws                                id  \
# 0    /players/b/bouchch01.html  2019   0.7  /players/b/bouchch01.html___2019
# 1    /players/p/pattoju01.html  2019   0.0  /players/p/pattoju01.html___2019
# 2    /players/d/doziepj01.html  2019   0.1  /players/d/doziepj01.html___2019
# 3    /players/l/lemonwa01.html  2019   0.1  /players/l/lemonwa01.html___2019
# 4    /players/h/hamilda02.html  2019  -0.1  /players/h/hamilda02.html___2019
# 5    /players/r/richama01.html  2019  -0.1  /players/r/richama01.html___2019
# 6    /players/l/lydonty01.html  2019   0.2  /players/l/lydonty01.html___2019
# 7    /players/d/dellama01.html  2019   0.5  /players/d/dellama01.html___2019
# 8     /players/r/rosede01.html  2019   3.0   /players/r/rosede01.html___2019
# 9    /players/m/morrimo01.html  2019   6.2  /players/m/morrimo01.html___2019
# 414  /players/j/joneste01.html  2019  -0.1  /players/j/joneste01.html___2019
# 415  /players/l/lucaska01.html  2019   0.0  /players/l/lucaska01.html___2019
# 416  /players/m/machasc01.html  2019   0.1  /players/m/machasc01.html___2019
# 417  /players/m/mcraejo01.html  2019   0.5  /players/m/mcraejo01.html___2019
# 418  /players/m/motiedo01.html  2019  -0.1  /players/m/motiedo01.html___2019
# 419  /players/r/randlch01.html  2019   0.6  /players/r/randlch01.html___2019
# 420  /players/s/stephdj01.html  2019   0.0  /players/s/stephdj01.html___2019
# 421  /players/j/jenkijo01.html  2019   0.2  /players/j/jenkijo01.html___2019
# 422  /players/k/knighbr03.html  2019   0.0  /players/k/knighbr03.html___2019
# 423  /players/n/nunnaja01.html  2019   0.1  /players/n/nunnaja01.html___2019
# 424   /players/w/woodch01.html  2019   0.8   /players/w/woodch01.html___2019
#
#       bpm  age    mp  C  F  G  ...  lot_of_min  ws_diff  bpm_diff  mp_diff  \
# 0     1.1   26   163  0  0  0  ...       False      NaN       NaN      NaN
# 1    -0.2   21    21  1  0  0  ...       False      NaN       NaN      NaN
# 2    -1.1   22    51  0  0  0  ...       False      NaN       NaN      NaN
# 3    -1.4   26   167  0  0  0  ...       False      NaN       NaN      NaN
# 4    -5.8   23   204  0  0  0  ...       False      NaN       NaN      NaN
# 5   -10.8   23   103  0  0  0  ...       False     -0.2      -0.9    126.0
# 6    -2.5   22    94  0  0  0  ...       False      NaN       NaN      NaN
# 7    -5.5   28   812  0  0  0  ...        True     -0.7      -1.2  -1274.0
# 8    -0.6   30  1392  0  0  0  ...        True     -3.2      -5.9  -1662.0
# 9     0.2   23  1970  0  0  0  ...       False      NaN       NaN      NaN
# 10   -1.1   25   516  0  0  0  ...       False      0.3       8.0    -61.0
# 11   -6.0   38  1211  0  0  0  ...        True     -0.6      -0.9   -504.0
# 12   -1.1   26   416  0  0  0  ...       False      NaN       NaN      NaN
# 13    9.5   23     1  0  0  0  ...       False      NaN       NaN      NaN
# 14   -4.0   22   259  0  0  0  ...       False      0.3       1.4    183.0
# 15    0.5   28  1863  0  0  0  ...        True    -10.4     -16.2  -2511.0
# 16  -14.1   38    74  1  0  0  ...       False     -0.3      -4.3    -58.0
# 17   -4.2   23    47  0  0  0  ...       False      NaN       NaN      NaN
# 18   -8.4   22   829  0  0  0  ...       False      NaN       NaN      NaN
# 19   -2.2   21   679  0  0  0  ...       False      NaN       NaN      NaN
# 20   -1.0   24  1961  0  0  0  ...       False      NaN       NaN      NaN
# 21   -1.4   30   292  0  0  0  ...       False      NaN       NaN      NaN
# 22   -3.4   33  1473  0  0  0  ...        True      1.5       2.8    391.0
# 23    3.0   23   410  1  0  0  ...       False      0.1       3.0      4.0
# 24  -14.0   20     6  1  0  0  ...       False      NaN       NaN      NaN
# 25   -0.5   22  1879  0  0  0  ...       False      0.1      -1.2    418.0
# 26   -5.3   36  1003  0  0  0  ...        True     -1.6      -1.1   -516.0
# 27   -4.3   28   212  0  0  0  ...       False      NaN       NaN      NaN
# 28   -3.2   23   156  0  0  0  ...       False      NaN       NaN      NaN
# 29   -7.3   30     1  0  0  0  ...       False      NaN       NaN      NaN
# ..    ...  ...   ... .. .. ..  ...         ...      ...       ...      ...
# 395   8.5   25  1850  1  0  0  ...        True      2.7       1.5     19.0
# 396   2.9   25  2647  1  0  0  ...        True      3.6       4.6    216.0
# 397   5.5   28  2838  0  0  0  ...        True      2.2       2.4    -24.0
# 398   3.1   32  2213  0  0  0  ...        True      0.1      -0.7    266.0
# 399   4.1   22  2700  0  0  0  ...        True      NaN       NaN      NaN
# 400   6.8   23  2545  1  0  0  ...        True      1.3       0.6   -112.0
# 401   4.3   30  2702  0  0  0  ...        True     -1.6      -2.4    255.0
# 402   3.6   28   771  1  0  0  ...        True     -2.9      -1.1   -728.0
# 403  10.8   24  2358  0  0  0  ...        True     -0.5      -1.8    -89.0
# 404   3.0   33  1857  0  0  0  ...        True     -0.4      -1.7    -74.0
# 405   5.0   27  2040  0  0  0  ...        True    -12.7      -2.0  -2264.0
# 406   9.5   23  2504  1  0  0  ...        True      1.0      -1.3    405.0
# 407   6.3   30  2331  0  0  0  ...        True     -3.5       1.3  -1007.0
# 408   8.1   34  1937  0  0  0  ...        True      1.1       1.2    232.0
# 409  11.7   29  2867  0  0  0  ...        True      0.4       0.8   -396.0
# 410   6.5   30  2630  0  0  0  ...        True     -3.0      -7.4    112.0
# 411  -8.9   25    84  0  0  0  ...       False      NaN       NaN      NaN
# 412  -1.3   28  1399  0  0  0  ...        True      NaN       NaN      NaN
# 413 -11.1   29    65  0  0  0  ...       False      NaN       NaN      NaN
# 414 -52.3   27     5  0  0  0  ...        True      NaN       NaN      NaN
# 415  -0.6   29     6  0  0  0  ...       False      NaN       NaN      NaN
# 416  -4.4   28    19  0  0  0  ...       False      NaN       NaN      NaN
# 417  -3.7   27   333  0  0  0  ...       False      NaN       NaN      NaN
# 418 -11.5   28    13  0  0  0  ...       False      NaN       NaN      NaN
# 419  -4.4   25   743  0  0  0  ...       False      NaN       NaN      NaN
# 420  -7.6   28     7  0  0  0  ...       False      NaN       NaN      NaN
# 421  -5.2   27   333  0  0  0  ...       False      NaN       NaN      NaN
# 422  -5.0   27   736  0  0  0  ...        True      NaN       NaN      NaN
# 423  -6.4   28   102  0  0  0  ...       False      NaN       NaN      NaN
# 424  -3.3   23   251  0  0  0  ...       False      NaN       NaN      NaN
#
#      bpm_int  bpm_diff_2  bpm_age_int  diff     pred_x    pred_y
# 0        NaN         NaN      -1534.0  60.1 -27.145053 -8.270845
# 1        NaN         NaN         69.3  -3.5  -8.730375 -3.391247
# 2        NaN         NaN       -748.0  32.9  -7.733395 -7.873882
# 3        NaN         NaN       -304.2  10.3  -6.583206 -6.481689
# 4        NaN         NaN        -36.8  -4.2  -6.365367 -3.047119
# 5      35.20         NaN       -147.2  -4.4  -5.738711 -4.580231
# 6        NaN         NaN       -143.0   4.0  -5.211629 -5.086721
# 7      27.73        -3.1       -165.2   0.4  -5.200312 -4.584083
# 8      14.82         1.4       -234.0   7.2  -5.016934 -5.683634
# 9        NaN         NaN         46.0  -1.8  -4.937921 -1.032753
# 10     48.00         NaN       -100.0   2.9  -4.744479 -4.475703
# 11     11.70        -0.4       -148.2  -2.1  -4.716257 -4.353130
# 12       NaN         NaN       -166.4   5.3  -4.629152 -4.049276
# 13       NaN         NaN       -165.6  16.7  -4.623245 -3.698207
# 14     55.76         NaN       -149.6   2.8  -4.453568 -4.353018
# 15    -50.40         1.7       -336.0  12.5  -4.453012 -1.812275
# 16     24.00         1.3       -285.0  -6.6  -4.428676 -4.683803
# 17       NaN         NaN       -154.1   2.5  -4.394779 -3.936642
# 18       NaN         NaN       -149.6  -1.6  -4.382747 -3.960397
# 19       NaN         NaN       -144.9   4.7  -4.326780 -4.075347
# 20       NaN         NaN        -98.4   3.1  -4.321147 -3.563648
# 21       NaN         NaN       -201.0   5.3  -4.318524 -4.341244
# 22      8.93        -1.7        -62.7  -1.5  -4.310125 -3.735844
# 23     63.36         NaN       -151.8   9.6  -4.241333 -5.561230
# 24       NaN         NaN       -108.0  -8.6  -4.207520 -3.898552
# 25     19.89         NaN       -112.2   4.6  -4.194636 -3.941532
# 26     12.30        -3.1       -147.6  -1.2  -4.193473 -3.381073
# 27       NaN         NaN        -84.0  -1.3  -4.175827 -4.721772
# 28       NaN         NaN       -112.7   1.7  -4.154785 -3.707317
# 29       NaN         NaN       -219.0   0.0  -4.148167 -4.433801
# ..       ...         ...          ...   ...        ...       ...
# 395    19.24         1.5        130.0   3.3   4.219306  4.277334
# 396     4.95         1.4        137.5  -2.6   4.760333  4.680105
# 397    28.81         0.6        187.6  -1.2   4.775242  5.145060
# 398    38.94        -0.2        188.8  -2.8   5.025455  5.058178
# 399      NaN         NaN        101.2  -0.5   5.075303  4.271252
# 400    26.95         2.1        126.5   1.3   5.148608  5.245210
# 401    44.80         0.1        168.0  -1.3   5.214463  5.452029
# 402    36.30         4.0        154.0  -1.9   5.683794  5.289697
# 403    44.08         5.2        139.2   5.0   5.739471  5.675749
# 404    62.48         1.0        234.3  -4.1   6.570346  6.053707
# 405    46.61        -0.4        159.3  -0.9   6.728587  6.547844
# 406    59.64         3.6        163.3   2.4   6.999172  6.075423
# 407    62.78        -5.2        258.0  -2.3   7.916815  7.313925
# 408    80.64        -0.7        326.4  -1.5   8.822306  7.700238
# 409   110.09         3.4        316.1   0.8   9.286165  9.313612
# 410   127.92         5.6        246.0  -1.7   9.651546  7.963369
# 411      NaN         NaN       1360.0 -63.3  40.953318 -5.024095
# 412      NaN         2.9          NaN   NaN        NaN -2.173813
# 413      NaN         NaN          NaN   NaN        NaN -4.321840
# 414      NaN         2.1          NaN   NaN        NaN -3.190856
# 415      NaN         NaN          NaN   NaN        NaN -4.303377
# 416      NaN         NaN          NaN   NaN        NaN -4.329154
# 417      NaN        -2.2          NaN   NaN        NaN -5.368572
# 418      NaN         1.2          NaN   NaN        NaN -4.193907
# 419      NaN         NaN          NaN   NaN        NaN -3.884572
# 420      NaN         NaN          NaN   NaN        NaN -4.406214
# 421      NaN         1.3          NaN   NaN        NaN -6.069450
# 422      NaN        -4.2          NaN   NaN        NaN -4.822072
# 423      NaN         NaN          NaN   NaN        NaN -4.406214
# 424      NaN         2.5          NaN   NaN        NaN -3.041822
#
# [425 rows x 82 columns]

# %%
def scorer(row, metric):
    row = row.fillna(0)
    summed = row['{}___1'.format(metric)] * row['mp___1']*3 + row['{}___2'.format(metric)] * row['mp___2']*2 + row['{}___3'.format(metric)] * row['mp___3']
    d =(row['mp___1']*3 + row['mp___2']*2 + row['mp___3'])
    if d > 0:
        return summed / d
    return -2

# %%
def scorer_bpm(row):
    return scorer(row, 'bpm')
def scorer_ws(row):
    return scorer(row, 'ws')
def max_bpm(row):
    return row[['bpm___1', 'bpm___2', 'bpm___3']].max()

# %%
recent['delta'] = recent['pred'] - recent.apply(scorer_ws, axis=1)
recent['delta'] = recent['pred'] - recent.apply(scorer_bpm, axis=1)
#recent['delta'] = recent['pred'] - recent.apply(max_bpm, axis=1)* 1

# %%
recent.sort_values('delta', ascending=False)[lambda x: x['pred'] > .5]
# Out:
#                       player_url  year    ws  \
# 21164    /players/f/foxde01.html  2020   5.6
# 21384  /players/s/sabondo01.html  2020   7.6
# 21035  /players/a/antetgi01.html  2020  14.4
# 21337  /players/n/nurkiju01.html  2020   7.8
# 21383  /players/r/russeda01.html  2020   5.0
# 21075  /players/b/bookede01.html  2020   3.5
# 21029  /players/a/allenja01.html  2020   7.6
# 21127  /players/d/davisan02.html  2020   9.5
# 21141  /players/d/doncilu01.html  2020   4.9
# 21023  /players/a/adebaba01.html  2020   6.8
# 21041  /players/a/aytonde01.html  2020   5.8
# 21237  /players/j/jacksja02.html  2020   3.3
# 21396  /players/s/smartma01.html  2020   5.3
# 21151  /players/e/embiijo01.html  2020   8.7
# 21179  /players/g/gordoaa01.html  2020   5.1
# 21316  /players/m/mitchdo01.html  2020   5.0
# 21246  /players/j/jokicni01.html  2020  11.8
# 21279  /players/l/looneke01.html  2020   6.0
# 21111  /players/c/collijo01.html  2020   6.0
# 21428  /players/v/vucevni01.html  2020  10.1
# 21422  /players/t/turnemy01.html  2020   6.3
# 21232  /players/i/irvinky01.html  2020   9.1
# 21393  /players/s/simmobe01.html  2020   8.2
# 21103  /players/c/caulewi01.html  2020   6.7
# 21391  /players/s/siakapa01.html  2020   9.3
# 21196  /players/h/harremo01.html  2020   8.7
# 21367  /players/r/randlju01.html  2020   6.1
# 21091  /players/b/bryanth01.html  2020   5.6
# 21156  /players/f/favorde01.html  2020   7.9
# 21443  /players/w/whitede01.html  2020   3.6
# ...                          ...   ...   ...
# 21280  /players/l/lopezbr01.html  2020   6.7
# 21177  /players/g/goberru01.html  2020  14.4
# 21187  /players/g/greenda02.html  2020   5.9
# 21227  /players/i/iguodan01.html  2020   4.2
# 21272  /players/l/leonaka01.html  2020   9.5
# 21103  /players/c/caulewi01.html___2020   2.0   26  2213  1  0  0  ...
# 21391  /players/s/siakapa01.html___2020   3.4   25  2548  0  0  0  ...
# 21196  /players/h/harremo01.html___2020   4.2   26  2158  1  0  0  ...
# 21367  /players/r/randlju01.html___2020   1.4   25  2232  0  0  0  ...
# 21091  /players/b/bryanth01.html___2020   1.6   22  1496  1  0  0  ...
# 21156  /players/f/favorde01.html___2020   4.3   28  1766  1  0  0  ...
# 21443  /players/w/whitede01.html___2020   0.9   25  1728  0  0  0  ...
# ...                                 ...   ...  ...   ... .. .. ..  ...
# 21280  /players/l/lopezbr01.html___2020   2.7   31  2322  1  0  0  ...
# 21177  /players/g/goberru01.html___2020   7.0   27  2577  1  0  0  ...
# 21187  /players/g/greenda02.html___2020   2.9   32  2216  0  0  0  ...
# 21227  /players/i/iguodan01.html___2020   1.9   36  1578  0  0  0  ...
# 21272  /players/l/leonaka01.html___2020   5.0   28  2040  0  0  0  ...
# 21432  /players/w/walkeke02.html___2020   3.3   29  2863  0  0  0  ...
# 21191  /players/g/griffbl01.html___2020   4.6   30  2622  0  0  0  ...
# 21068  /players/b/bledser01.html___2020   3.5   30  2272  0  0  0  ...
# 21504  /players/j/jordade01.html___2020   2.4   31  2047  1  0  0  ...
# 21314  /players/m/millspa01.html___2020   2.4   34  1895  0  0  0  ...
# 21489  /players/g/gasolma01.html___2020   2.8   35  2436  1  0  0  ...
# 21188  /players/g/greendr01.html___2020   2.0   29  2065  0  0  0  ...
# 21063  /players/b/beverpa01.html___2020   2.3   31  2137  0  0  0  ...
# 21148  /players/d/duranke01.html___2020   4.3   31  2702  0  0  0  ...
# 21026  /players/a/aldrila01.html___2020   1.6   34  2687  1  0  0  ...
# 21472  /players/b/butleji01.html___2020   3.2   30  2185  0  0  0  ...
# 21229  /players/i/inglejo01.html___2020   1.8   32  2568  0  0  0  ...
# 21240  /players/j/jamesle01.html___2020   8.1   35  1937  0  0  0  ...
# 21307  /players/m/mejrisa01.html___2020   1.9   33   399  1  0  0  ...
# 21033  /players/a/anderky01.html___2020   1.2   26  1281  0  0  0  ...
# 21283  /players/l/lowryky01.html___2020   3.1   33  2213  0  0  0  ...
# 21353   /players/p/paulch01.html___2020   3.0   34  1857  0  0  0  ...
# 21125  /players/c/curryst01.html___2020   6.3   31  2331  0  0  0  ...
# 21528  /players/p/porteot01.html___2020   0.5   26  1683  0  0  0  ...
# 21340  /players/o/oquinky01.html___2020   1.8   29   371  1  0  0  ...
# 21423   /players/u/udohek01.html___2020   5.6   32   320  1  0  0  ...
# 21115  /players/c/conlemi01.html___2020   3.4   32  2342  0  0  0  ...
# 21118  /players/c/couside01.html___2020   3.6   29   771  1  0  0  ...
# 21490  /players/g/gasolpa01.html___2020   0.6   39   360  1  0  0  ...
# 21442  /players/w/westbru01.html___2020   6.5   31  2630  0  0  0  ...
#
#        lot_of_min  ws_diff  bpm_diff  mp_diff  bpm_int  bpm_diff_2  \
# 21164        True      6.2       5.5    520.0    -4.84         NaN
# 21384        True      2.9       4.0     28.0    -1.11         4.5
# 21035        True      2.5       5.0   -398.0    62.64        -1.8
# 21337        True      3.1       4.8   -114.0     1.53         0.5
# 21383        True      4.6       3.8   1214.0    -1.36         0.1
# 21075        True      1.1       0.4    377.0     0.32         2.7
# 21029        True      3.4       2.3    655.0     0.50         NaN
# 21127        True     -4.2       3.3   -877.0    44.20         1.5
# 21141        True      NaN       NaN      NaN      NaN         NaN
# 21023        True      2.6       2.8    545.0     0.60         NaN
# 21041        True      NaN       NaN      NaN      NaN         NaN
# 21237        True      NaN       NaN      NaN      NaN         NaN
# 21396        True      3.4       2.3    586.0    -0.90        -0.2
# 21151        True      2.5       1.5    242.0    10.66        -0.5
# 21179        True      2.2       1.0    724.0     0.00         0.7
# 21316        True     -0.2      -0.5    -40.0     0.66         NaN
# 21246        True      1.1       2.4     61.0    67.45        -1.3
# 21279        True      3.2       2.5    571.0     4.44         0.8
# 21111        True      0.6      -0.3     44.0     2.38         NaN
# 21428        True      6.5       3.7    827.0    17.28         1.8
# 21422        True      1.6       2.6    283.0     2.31        -1.7
# 21232        True      0.2       0.2    283.0    39.68         3.7
# 21393        True     -1.0      -0.5    -32.0    18.86         NaN
# 21103        True      2.8       1.6    169.0     0.80         1.6
# 21391        True      4.6       1.3    869.0     7.14         3.2
# 21196        True      3.2       1.8    865.0    10.08         1.5
# 21367        True     -0.5       0.5     42.0     1.26         0.9
# 21091        True      5.5       5.8   1424.0    -6.72         NaN
# 21156        True     -0.1       1.6   -387.0    11.61         2.8
# 21443        True      3.1       0.4   1589.0     0.45         NaN
# ...           ...      ...       ...      ...      ...         ...
# 21280        True      2.9       2.2    587.0     1.35        -1.0
# 21177        True      6.3       2.7    761.0    30.10        -1.5
# 21187        True      3.0       1.7    425.0     3.48        -1.2
# 21227        True      1.0       1.7    -44.0     0.38        -2.8
# 21272        True      8.6      -0.9   1830.0    29.50        -2.0
# 21432        True     -1.2       0.1    127.0    10.56        -0.4
# 21191        True      3.1       1.8    652.0    12.88        -1.6
# 21068        True      2.6       1.4    -50.0     7.35        -1.2
# 21504        True     -2.3       0.3   -377.0     5.04        -2.0
# 21314        True      3.6       1.6    752.0     1.92        -1.9
# 21489        True      2.0       1.3     28.0     4.20        -2.7
# 21188        True     -1.8      -1.2   -222.0     6.40        -2.2
# 21063        True      4.4       1.4   1803.0     2.07        -1.4
# 21148        True      1.1      -1.3    377.0    24.08        -2.4
# 21026        True     -1.6      -1.7    178.0     5.28         2.3
# 21472        True     -1.0      -1.8     21.0    16.00        -1.9
# 21229        True     -1.6      -1.3    -10.0     5.58         0.4
# 21240        True     -6.8      -1.5  -1089.0    77.76         1.2
# 21307        True     -1.6      -1.2   -330.0     5.89         2.9
# 21033        True     -3.5      -2.9   -697.0     4.92         2.5
# 21283        True     -3.6      -2.8   -297.0    18.29        -0.7
# 21353        True     -3.6      -4.1     10.0    21.30        -1.7
# 21125        True      0.6      -2.3    700.0    54.18         1.3
# 21037  /players/a/anthoca01.html  2020   0.3
# 21328  /players/n/naderab01.html  2020   0.9
# 21094  /players/c/caldejo01.html  2020   0.6
# 21121  /players/c/crawfja01.html  2020   0.2
# 21349  /players/p/parketo01.html  2020   0.9
# 21481  /players/d/dellama01.html  2020   0.5
# 21067  /players/b/blakean01.html  2020  -0.5
# 21410  /players/t/thomais02.html  2020  -0.3
#
#                                      id   bpm  age    mp  C  F  G  ...  \
# 21194  /players/h/hardeja01.html___2020  11.7   30  2867  0  0  0  ...
# 21035  /players/a/antetgi01.html___2020  10.8   25  2358  0  0  0  ...
# 21246  /players/j/jokicni01.html___2020   9.5   24  2504  1  0  0  ...
# 21240  /players/j/jamesle01.html___2020   8.1   35  1937  0  0  0  ...
# 21127  /players/d/davisan02.html___2020   8.5   26  1850  1  0  0  ...
# 21442  /players/w/westbru01.html___2020   6.5   31  2630  0  0  0  ...
# 21417  /players/t/townska01.html___2020   6.8   24  2545  1  0  0  ...
# 21232  /players/i/irvinky01.html___2020   6.4   27  2214  0  0  0  ...
# 21125  /players/c/curryst01.html___2020   6.3   31  2331  0  0  0  ...
# 21177  /players/g/goberru01.html___2020   7.0   27  2577  1  0  0  ...
# 21377  /players/r/robinmi01.html___2020   5.7   21  1360  1  0  0  ...
# 21276  /players/l/lillada01.html___2020   5.5   29  2838  0  0  0  ...
# 21272  /players/l/leonaka01.html___2020   5.0   28  2040  0  0  0  ...
# 21141  /players/d/doncilu01.html___2020   4.1   20  2318  0  0  0  ...
# 21428  /players/v/vucevni01.html___2020   6.4   29  2510  1  0  0  ...
# 21393  /players/s/simmobe01.html___2020   4.1   23  2700  0  0  0  ...
# 21148  /players/d/duranke01.html___2020   4.3   31  2702  0  0  0  ...
# 21337  /players/n/nurkiju01.html___2020   5.1   25  1974  1  0  0  ...
# 21151  /players/e/embiijo01.html___2020   4.1   25  2154  1  0  0  ...
# 21423   /players/u/udohek01.html___2020   5.6   32   320  1  0  0  ...
# 21353   /players/p/paulch01.html___2020   3.0   34  1857  0  0  0  ...
# 21173  /players/g/georgpa01.html___2020   5.5   29  2841  0  0  0  ...
# 21219  /players/h/horfoal01.html___2020   4.8   33  1973  1  0  0  ...
# 21118  /players/c/couside01.html___2020   3.6   29   771  1  0  0  ...
# 21196  /players/h/harremo01.html___2020   4.2   26  2158  1  0  0  ...
# 21472  /players/b/butleji01.html___2020   3.2   30  2185  0  0  0  ...
# 21329  /players/n/nancela02.html___2020   4.0   27  1795  1  0  0  ...
# 21359  /players/p/poeltja01.html___2020   4.2   24  1273  1  0  0  ...
# 21283  /players/l/lowryky01.html___2020   3.1   33  2213  0  0  0  ...
# 21191  /players/g/griffbl01.html___2020   4.6   30  2622  0  0  0  ...
# ...                                 ...   ...  ...   ... .. .. ..  ...
# 21306  /players/m/meeksjo01.html___2020  -0.8   32   104  0  0  0  ...
# 21398  /players/s/smithjr01.html___2020  -5.2   34   222  0  0  0  ...
# 21042  /players/b/bacondw01.html___2020  -3.5   24   759  0  0  0  ...
# 21341  /players/o/ojelese01.html___2020  -4.3   25   594  0  0  0  ...
# 21020    /players/a/acyqu01.html___2020  -5.9   29   123  0  0  0  ...
# 21473  /players/c/canaais01.html___2020  -5.1   28   629  0  0  0  ...
# 21494  /players/h/harrian01.html___2020  -6.6   25   187  0  0  0  ...
# 21083  /players/b/brookdi01.html___2020  -6.1   24   330  0  0  0  ...
# 21109  /players/c/clarkia01.html___2020  -5.1   28   973  0  0  0  ...
# 21304  /players/m/mclembe01.html___2020  -3.7   26   158  0  0  0  ...
# 21463  /players/a/anderry01.html___2020  -6.4   31   322  0  0  0  ...
# 21511  /players/l/luwawti01.html___2020  -5.0   24   669  0  0  0  ...
# 21189  /players/g/greenge01.html___2020  -3.4   34  1473  0  0  0  ...
# 21336  /players/n/ntilila01.html___2020  -5.7   21   904  0  0  0  ...
# 21533  /players/s/seldewa01.html___2020  -5.1   25  1439  0  0  0  ...
# 21512   /players/m/macksh01.html___2020  -4.1   29  1246  0  0  0  ...
# 21158  /players/f/feltora01.html___2020  -4.2   35   379  0  0  0  ...
# 21126  /players/d/danietr01.html___2020  -4.4   28   760  0  0  0  ...
# 21412  /players/t/thomala01.html___2020  -5.3   31   783  0  0  0  ...
# 21259   /players/k/knoxke01.html___2020  -6.0   20  2158  0  0  0  ...
# 21051  /players/b/bayleje01.html___2020  -5.1   31   657  0  0  0  ...
# 21407  /players/t/teodomi01.html___2020  -6.1   32   150  0  0  0  ...
# 21037  /players/a/anthoca01.html___2020  -5.9   35   294  0  0  0  ...
# 21328  /players/n/naderab01.html___2020  -5.1   26   694  0  0  0  ...
# 21094  /players/c/caldejo01.html___2020  -5.1   38   632  0  0  0  ...
# 21121  /players/c/crawfja01.html___2020  -6.0   39  1211  0  0  0  ...
# 21349  /players/p/parketo01.html___2020  -5.3   37  1003  0  0  0  ...
# 21481  /players/d/dellama01.html___2020  -5.5   29   812  0  0  0  ...
# 21067  /players/b/blakean01.html___2020  -8.4   23   829  0  0  0  ...
# 21410  /players/t/thomais02.html___2020  -8.7   30   181  0  0  0  ...
#
#        lot_of_min  ws_diff  bpm_diff  mp_diff  bpm_int  bpm_diff_2  \
# 21194        True     -0.2       0.8    316.0   127.53         0.8
# 21035        True      2.5       5.0   -398.0    62.64        -1.8
# 21246        True      1.1       2.4     61.0    67.45        -1.3
# 21240        True     -6.8      -1.5  -1089.0    77.76         1.2
# 21127        True     -4.2       3.3   -877.0    44.20         1.5
# 21442        True     -3.3      -1.7   -284.0    53.30        -7.4
# 21417        True     -3.6       1.3   -373.0    37.40         0.6
# 21232        True      0.2       0.2    283.0    39.68         3.7
# 21125        True      0.6      -2.3    700.0    54.18         1.3
# 21177        True      6.3       2.7    761.0    30.10        -1.5
# 21377        True      NaN       NaN      NaN      NaN         NaN
# 21276        True     -0.5      -1.2    168.0    36.85         2.4
# 21272        True      8.6      -0.9   1830.0    29.50        -2.0
# 21141        True      NaN       NaN      NaN      NaN         NaN
# 21428        True      6.5       3.7    827.0    17.28         1.8
# 21393        True     -1.0      -0.5    -32.0    18.86         NaN
# 21148        True      1.1      -1.3    377.0    24.08        -2.4
# 21337        True      3.1       4.8   -114.0     1.53         0.5
# 21151        True      2.5       1.5    242.0    10.66        -0.5
# 21423        True     -1.6      -0.1   -490.0    31.92         NaN
# 21353        True     -3.6      -4.1     10.0    21.30        -1.7
# 21173        True      3.0       3.0    -50.0    13.75        -0.3
# 21219        True     -0.3       0.8   -304.0    19.20         0.9
# 21118        True     -2.3      -1.9   -966.0    19.80        -1.1
# 21196        True      3.2       1.8    865.0    10.08         1.5
# 21472        True     -1.0      -1.8     21.0    16.00        -1.9
# 21329        True     -0.9       0.7    374.0    13.20         1.4
# 21359        True     -0.5       0.9   -251.0    13.86         4.0
# 21283        True     -3.6      -2.8   -297.0    18.29        -0.7
# 21191        True      3.1       1.8    652.0    12.88        -1.6
# ...           ...      ...       ...      ...      ...         ...
# 21306        True     -1.7       2.0  -1015.0     2.24        -1.0
# 21398        True     -1.6      -3.5  -2022.0     8.84        -0.4
# 21042        True      1.3       2.2     46.0    19.95         NaN
# 21341        True     -0.5      -0.8   -556.0    15.05         NaN
# 21020        True     -1.1      -3.7  -1236.0    12.98         0.8
# 21473        True     -0.5      -2.7    207.0    12.24         1.0
# 21494        True     -1.8      -4.1  -1139.0    16.50        -0.1
# 21083        True     -1.2      -3.0  -2020.0    18.91         NaN
# 21109        True     -1.2      -1.2   -482.0    19.89        -1.9
# 21304        True     -0.3      -0.1   -933.0    13.32         1.3
# 21463        True     -5.0      -6.6  -1403.0    -1.28         1.0
# 21511        True     -0.6      -0.3   -138.0    23.50        -0.7
# 21189        True     -0.2      -1.5    544.0     6.46         2.8
# 21336        True      0.1      -1.8   -802.0    22.23         NaN
# 21533        True     -0.6      -1.1    747.0    20.40         1.0
# 21512        True     -1.0      -1.7   -119.0     9.84        -0.6
# 21158        True     -1.5      -1.4   -986.0    11.76        -1.8
# 21126        True     -1.1      -1.5   -862.0    12.76         0.2
# 21412        True     -0.8      -2.7   -570.0    13.78         1.1
# 21259        True      NaN       NaN      NaN      NaN         NaN
# 21051        True     -1.1      -2.4   -268.0    13.77         5.5
# 21407        True     -1.5      -4.7   -984.0     8.54         NaN
# 21037        True     -3.4      -2.1  -2207.0    22.42        -3.1
# 21328        True      1.0       0.5    172.0    28.56         NaN
# 21094        True     -1.2      -3.2   -282.0     9.69         2.8
# 21121        True     -1.1      -2.1   -442.0    23.40        -0.9
# 21349        True     -0.5      -1.2    -68.0    21.73        -1.1
# 21481        True      0.0       0.4    100.0    32.45        -1.2
# 21067        True     -0.5      -1.6    515.0    57.12         NaN
# 21410        True     -0.5      -3.5   -681.0    45.24       -10.6
#
#        bpm_age_int  diff       pred     delta
# 21194        351.0   0.0  11.084683 -0.086981
# 21035        270.0   0.0   9.740313  1.316309
# 21246        228.0   0.0   8.848674  0.316269
# 21240        283.5   0.0   7.489493 -1.287057
# 21127        221.0   0.0   7.033087  0.793633
# 21442        201.5   0.0   6.234210 -2.408999
# 21417        163.2   0.0   5.731027 -0.260307
# 21232        172.8   0.0   5.669528  0.084625
# 21125        195.3   0.0   5.515595 -1.570925
# 21177        189.0   0.0   5.306386 -0.765053
# 21377        119.7   0.0   5.287981 -0.412019
# 21276        159.5   0.0   4.969644 -0.722234
# 21272        140.0   0.0   4.914307 -0.923568
# 21141         82.0   0.0   4.873589  0.773589
# 21428        185.6   0.0   4.713381  0.178049
# 21393         94.3   0.0   4.378722  0.077307
# 21148        133.3   0.0   4.041384 -1.182938
# 21337        127.5   0.0   4.029698  1.316076
# 21151        102.5   0.0   3.931094  0.420147
# 21423        179.2   0.0   3.842723 -1.820068
# 21353        102.0   0.0   3.784693 -1.565316
# 21173        159.5   0.0   3.722752 -0.329307
# 21219        158.4   0.0   3.525187 -0.692838
# 21118        104.4   0.0   3.454423 -1.841602
# 21196        109.2   0.0   3.364918 -0.028484
# 21472         96.0   0.0   3.269617 -1.258435
# 21329        108.0   0.0   3.259450 -0.221614
# 21359        100.8   0.0   3.247492 -0.177038
# 21283        102.3   0.0   3.175792 -1.500127
# 21191        138.0   0.0   3.111734 -0.947479
# ...            ...   ...        ...       ...
# 21306        -25.6   0.0  -3.786636 -1.400870
# 21398       -176.8   0.0  -3.806848 -1.814118
# 21042        -84.0   0.0  -3.834187  0.513018
# 21341       -107.5   0.0  -3.879951 -0.030711
# 21020       -171.1   0.0  -3.900064 -1.203027
# 21473       -142.8   0.0  -3.940524  0.170851
# 21494       -165.0   0.0  -4.077529 -1.118237
# 21083       -146.4   0.0  -4.092654 -0.470686
# 21109       -142.8   0.0  -4.140202 -0.047480
# 21304        -96.2   0.0  -4.161279 -0.149954
# 21463       -198.4   0.0  -4.161848 -3.061848
# 21511       -120.0   0.0  -4.175819  0.476187
# 21189       -115.6   0.0  -4.190433 -1.096757
# 21336       -119.7   0.0  -4.206994  0.490132
# 21533       -127.5   0.0  -4.211634  0.627965
# 21512       -118.9   0.0  -4.240510 -1.106560
# 21158       -147.0   0.0  -4.331639 -1.795372
# 21126       -123.2   0.0  -4.385886 -0.940695
# 21412       -164.3   0.0  -4.394227 -0.564424
# 21259       -120.0   0.0  -4.406394  1.593606
# 21051       -158.1   0.0  -4.428549 -0.412799
# 21407       -195.2   0.0  -4.491583 -2.313438
# 21037       -206.5   0.0  -4.712834 -1.627106
# 21328       -132.6   0.0  -4.783993  0.482993
# 21094       -193.8   0.0  -5.418220 -1.740974
# 21121       -234.0   0.0  -5.495399 -0.970069
# 21349       -196.1   0.0  -5.541779 -1.164976
# 21481       -159.5   0.0  -5.958201 -0.632542
# 21067       -193.2   0.0  -6.682897  1.394535
# 21410       -261.0   0.0  -6.738425 -6.776411
#
# [373 rows x 82 columns]

# %%
studs = all_df[(all_df['years_pro'] == 1) & (all_df['lot_of_min']) & (all_df['bpm___1'] > 2.0)][lambda x: x['year']!=2020]

studs['diff'] = studs['bpm'] - studs['bpm___1']

studs.sort_values('year')[['player_url', 'diff']]

# %%
all_df['lot_of_min'] = (
    all_df['bpm___1'].notnull()
    #& ((all_df['mp___1'].fillna(0) + all_df['mp___2'].fillna(0)) > 1000)
    & (all_df['mp___1'].fillna(0) > 1000)
    &(all_df['years_pro'] < 3)
    
)

# %%
train_df = all_df[
    (all_df['year'] > 1970) 
    & (all_df['year'] < 2000) 
    & (all_df['years_pro'] > 0) 
]

# %%
high_train = train_df[train_df['lot_of_min']]
low_train = train_df[~train_df['lot_of_min']]
high_all = all_df[all_df['lot_of_min']]
low_all = all_df[~all_df['lot_of_min']]

# %%
y_high = high_train['diff']
X_high = high_train.drop(drop_cols, 1)
X_all_high = high_all.drop(drop_cols, 1)

# %%
y_low = low_train['bpm']
X_low = low_train.drop(drop_cols, 1)
X_all_low = low_all.drop(drop_cols, 1)

# %%
X_high.shape
# Out:
# (1181, 73)

# %%
weights = np.log10(high_train['mp']+1) 
lgb_data = lgb.Dataset(X_high, y_high, weight=weights)
out = lgb.cv(lgb_params, lgb_data, num_boost_round=10000, nfold=5,
             early_stopping_rounds=10,stratified=False)
cv_loss = out['rmse-mean'][-1]
cv_num_rounds = len(out['rmse-mean'])

cv_loss, cv_num_rounds
# Out:
# (2.0048456528381964, 23)

# %%
bst_high = lgb.LGBMRegressor(n_estimators=cv_num_rounds, **lgb_params).fit(X_high, y_high, sample_weight=weights)

# %%
weights = np.log10(low_train['mp']+1) 
lgb_data = lgb.Dataset(X_low, y_low)
out = lgb.cv(lgb_params, lgb_data, num_boost_round=10000, nfold=5,
             early_stopping_rounds=10,stratified=False)
cv_loss = out['rmse-mean'][-1]
cv_num_rounds = len(out['rmse-mean'])

cv_loss, cv_num_rounds
# Out:
# (3.330401118917867, 63)

# %%
bst_low = lgb.LGBMRegressor(n_estimators=cv_num_rounds, **lgb_params).fit(X_low, y_low, sample_weight=weights)

# %%
preds_high = bst_high.predict(X_all_high)
high_all['pred'] = preds_high + high_all['bpm___1']
# Out:
# /Users/harrisonchase/workplace/.venvs/record_linking/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
preds_low = bst_low.predict(X_all_low)
low_all['pred'] = preds_low
# Out:
# /Users/harrisonchase/workplace/.venvs/record_linking/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
recent.shape
# Out:
# (7415, 82)

# %%
all_joined = pd.concat([high_all, low_all])

# %%
recent = all_joined[(all_joined['year'] > 2000) & (all_joined['year'] < 2020)].sort_values('pred')
recent = recent[(recent['years_pro'] > 0)]

# %%
recent.shape
# Out:
# (7415, 81)

# %%
recent['error'] = (recent['bpm'] - recent['pred'])**2

# %%
((recent['error'])**.5).mean()
# Out:
# 1.9659955980914825

# %%
#recent1 = recent.copy()

# %%
huh = recent[['id', 'bpm', 'bpm___1', 'mp___1','error']].merge(recent1[['id', 'error']], on='id')

# %%
huh[huh['error_x']!=huh['error_y']]
# Out:
#                                    id   bpm  bpm___1  mp___1     error_x  \
# 0    /players/b/bouchch01.html___2019   1.1    -59.0     1.0   90.533179
# 1    /players/d/doziepj01.html___2019  -1.1    -34.0     3.0   48.980944
# 827  /players/a/antetgi01.html___2019  10.8      5.8  2756.0   27.654779
# 828  /players/d/duranke01.html___2019   4.3      5.6  2325.0    1.698166
# 829  /players/j/jokicni01.html___2019   9.5      7.1  2443.0   14.512176
# 830  /players/a/antetgi01.html___2018   5.8      7.6  2845.0    0.002633
# 831   /players/p/paulch01.html___2019   3.0      7.1  1847.0    7.638500
# 832  /players/l/leonaka01.html___2019   5.0      5.9   210.0    1.513810
# 833  /players/j/jamesle01.html___2018   9.6      8.4  2794.0    7.793192
# 834  /players/l/leonaka01.html___2018   5.9      7.9  2474.0    1.068673
# 835  /players/c/curryst01.html___2019   6.3      8.6  1631.0    0.840892
# 836  /players/d/duranke01.html___2018   5.6      8.0  2070.0    2.724409
# 837  /players/c/curryst01.html___2018   8.6      7.3  2638.0    1.817439
# 838  /players/j/jamesle01.html___2019   8.1      9.6  3026.0    0.430270
# 839  /players/w/westbru01.html___2019   6.5      8.2  2914.0    1.070284
# 840   /players/p/paulch01.html___2018   7.1      8.8  1921.0    0.191279
# 841  /players/h/hardeja01.html___2019  11.7     10.9  2551.0    8.909896
# 842  /players/j/jokicni01.html___2018   7.1      8.4  2038.0    2.665528
# 843  /players/h/hardeja01.html___2018  10.9     10.1  2947.0    3.736793
# 844  /players/w/westbru01.html___2018   8.2     15.6  2802.0    0.661276
#
#         error_y
# 0     49.131705
# 1     25.296974
# 2     13.947940
# 3      9.060543
# 4      7.302324
# 5     48.968067
# 6     19.700612
# 7      0.856790
# 8    454.536506
# 9      1.953618
# 10     1.514875
# 11     0.774643
# 12     0.100285
# 13    52.606721
# 14     2.493763
# 15    83.001239
# 16     8.986317
# 17    39.661261
# 18     0.702940
# 19     0.357268
# 20     3.267575
# 21     3.987559
# 22    54.726242
# 23    14.251444
# 24     4.382511
# 25     0.498164
# 26     0.000022
# 27     0.693964
# 28     2.298339
# 29    10.934139
# ..          ...
# 815    2.858505
# 816    0.128996
# 817    0.328148
# 818    4.912654
# 819    1.238941
# 820    0.012197
# 821    0.300624
# 822    0.386151
# 823    1.077623
# 824    4.578943
# 825    0.655939
# 826    4.849035
# 827   26.680815
# 828    1.885762
# 829    5.634130
# 830    0.942333
# 831   10.864983
# 832    1.209475
# 833    4.829905
# 834    1.536013
# 835    1.621688
# 836    2.133435
# 837    0.034951
# 838    0.014033
# 839    6.884022
# 840    0.230279
# 841    2.141586
# 842    0.920514
# 843    2.864523
# 844   44.705764
#
# [845 rows x 6 columns]

# %%
recent[recent['id'] == '/players/c/curryse01.html___2019']
# Out:
#                       player_url  year   ws                                id  \
# 18503  /players/c/curryse01.html  2019  2.4  /players/c/curryse01.html___2019
#
#        bpm  age    mp  C  F  G  ...  lot_of_min  ws_diff  bpm_diff  mp_diff  \
# 18503 -1.3   28  1399  0  0  0  ...        True      NaN       NaN      NaN
#
#        bpm_int  bpm_diff_2  bpm_age_int  diff  pred  error
# 18503      NaN         2.9          NaN   NaN   NaN    NaN
#
# [1 rows x 82 columns]
